# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
load_dotenv()
# Out:
# True

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
print(f"Total articles about Bitcoin: {bitcoin_headlines['totalResults']}")
# Out:
# Total articles about Bitcoin: 3706

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
print(f"Total articles about Ethereum: {ethereum_headlines['totalResults']}")
# Out:
# Total articles about Ethereum: 1397

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-09-10  Two alleged crypto traders in Singapore appare...   -0.6908
# 1  2020-09-08  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...    0.0000
# 2  2020-08-23  “The COVID-19 pandemic has resulted in a mass ...    0.2732
# 3  2020-09-08  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000
# 4  2020-09-08  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000
#
#    positive  negative  neutral
# 0     0.000      0.16    0.840
# 1     0.000      0.00    1.000
# 2     0.063      0.00    0.937
# 3     0.000      0.00    1.000
# 4     0.000      0.00    1.000

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-09-02  If you've interacted with cryptocurrencies in ...    0.7506
# 1  2020-09-07  TL;DR: The Complete Stock and Cryptocurrency I...    0.0000
# 2  2020-09-18  September\r\n18, 2020\r\n6 min read\r\nOpinion...    0.0000
# 3  2020-08-26  LONDON (Reuters) - It sounds like a surefire b...    0.7579
# 4  2020-08-25  NEW YORK (Reuters) - Brooklyn-based technology...    0.0000
#
#    positive  negative  neutral
# 0     0.209       0.0    0.791
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.181       0.0    0.819
# 4     0.000       0.0    1.000

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  94.000000  94.000000  94.000000  94.000000
# mean    0.138830   0.074543   0.044426   0.881032
# std     0.469551   0.062096   0.069038   0.083554
# min    -0.865800   0.000000   0.000000   0.588000
# 25%    -0.133425   0.007000   0.000000   0.823250
# 50%     0.271400   0.082500   0.000000   0.910000
# 75%     0.507000   0.093000   0.087250   0.921750
# max     0.923100   0.314000   0.294000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  94.000000  94.000000  94.000000  94.000000
# mean    0.138898   0.068979   0.035819   0.895191
# std     0.403996   0.068393   0.066314   0.087403
# min    -0.910000   0.000000   0.000000   0.607000
# 25%     0.000000   0.000000   0.000000   0.841500
# 50%     0.140300   0.067000   0.000000   0.909000
# 75%     0.416600   0.101000   0.063000   0.958750
# max     0.851900   0.311000   0.347000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Complete the tokenizer function
def tokenizer(input):
    words = word_tokenize(re.compile("[^a-zA-Z ]").sub('', str(input)))
    lem = [WordNetLemmatizer().lemmatize(i) for i in words]
    tokens= [i.lower() for i in lem if i.lower() not in set(stopwords.words('english'))]
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-09-10  Two alleged crypto traders in Singapore appare...   -0.6908
# 1  2020-09-08  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...    0.0000
# 2  2020-08-23  “The COVID-19 pandemic has resulted in a mass ...    0.2732
# 3  2020-09-08  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000
# 4  2020-09-08  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000
#
#    positive  negative  neutral  \
# 0     0.000      0.16    0.840
# 1     0.000      0.00    1.000
# 2     0.063      0.00    0.937
# 3     0.000      0.00    1.000
# 4     0.000      0.00    1.000
#
#                                               tokens
# 0  [two, alleged, crypto, trader, singapore, appa...
# 1  [alexis, akwagyiram, tom, wilson, monthly, cry...
# 2  [covid, pandemic, ha, resulted, mass, shift, w...
# 3  [lagoslondon, reuters, four, month, ago, abola...
# 4  [lagoslondon, reuters, four, month, ago, abola...

# %%
# Create a new tokens column for ethereum
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-09-02  If you've interacted with cryptocurrencies in ...    0.7506
# 1  2020-09-07  TL;DR: The Complete Stock and Cryptocurrency I...    0.0000
# 2  2020-09-18  September\r\n18, 2020\r\n6 min read\r\nOpinion...    0.0000
# 3  2020-08-26  LONDON (Reuters) - It sounds like a surefire b...    0.7579
# 4  2020-08-25  NEW YORK (Reuters) - Brooklyn-based technology...    0.0000
#
#    positive  negative  neutral  \
# 0     0.209       0.0    0.791
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.181       0.0    0.819
# 4     0.000       0.0    1.000
#
#                                               tokens
# 0  [youve, interacted, cryptocurrencies, past, co...
# 1  [tldr, complete, stock, cryptocurrency, invest...
# 2  [september, min, readopinions, expressed, entr...
# 3  [london, reuters, sound, like, surefire, bet, ...
# 4  [new, york, reuters, brooklynbased, technology...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_ngrams = [Counter(ngrams(i, n=2)) for i in bitcoin_df['tokens']]
bitcoin_ngrams
# Out:
# [Counter({('two', 'alleged'): 1,
#           ('alleged', 'crypto'): 1,
#           ('crypto', 'trader'): 1,
#           ('trader', 'singapore'): 1,
#           ('singapore', 'apparently'): 1,
#           ('apparently', 'came'): 1,
#           ('came', 'foolproof'): 1,
#           ('foolproof', 'plan'): 1,
#           ('plan', 'rather'): 1,
#           ('rather', 'convert'): 1,
#           ('convert', 'customer'): 1,
#           ('customer', 'singapore'): 1,
#           ('singapore', 'dollar'): 1,
#           ('dollar', 'bitcoin'): 1,
#           ('bitcoin', 'would'): 1,
#           ('would', 'simply'): 1,
#           ('simply', 'rob'): 1,
#           ('rob', 'victim'): 1,
#           ('victim', 'came'): 1,
#           ('came', 'char'): 1}),
#  Counter({('alexis', 'akwagyiram'): 1,
#           ('akwagyiram', 'tom'): 1,
#           ('tom', 'wilson'): 1,
#           ('wilson', 'monthly'): 1,
#           ('monthly', 'crypto'): 1,
#           ('crypto', 'transfer'): 1,
#           ('transfer', 'africa'): 1,
#           ('africa', 'rise'): 1,
#           ('rise', 'year'): 1,
#           ('year', 'much'): 1,
#           ('much', 'activity'): 1,
#           ('activity', 'nigeria'): 1,
#           ('nigeria', 'south'): 1,
#           ('south', 'africa'): 1,
#           ('africa', 'kenya'): 1,
#           ('kenya', 'driven'): 1,
#           ('driven', 'small'): 1,
#           ('small', 'business'): 1,
#           ('business', 'migrant'): 1,
#           ('migrant', 'char'): 1}),
#  Counter({('covid', 'pandemic'): 1,
#           ('pandemic', 'ha'): 1,
#           ('ha', 'resulted'): 1,
#           ('resulted', 'mass'): 1,
#           ('mass', 'shift'): 1,
#           ('shift', 'working'): 1,
#           ('working', 'home'): 1,
#           ('home', 'resulting'): 1,
#           ('resulting', 'increased'): 1,
#           ('increased', 'use'): 1,
#           ('use', 'corporate'): 1,
#           ('corporate', 'vpn'): 1,
#           ('vpn', 'elimination'): 1,
#           ('elimination', 'inperson'): 1,
#           ('inperson', 'verification'): 1,
#           ('verification', 'partially'): 1,
#           ('partially', 'explain'): 1,
#           ('explain', 'succes'): 1,
#           ('succes', 'char'): 1}),
#  Counter({('lagoslondon', 'reuters'): 1,
#           ('reuters', 'four'): 1,
#           ('four', 'month'): 1,
#           ('month', 'ago'): 1,
#           ('ago', 'abolaji'): 1,
#           ('abolaji', 'odunjo'): 1,
#           ('odunjo', 'made'): 1,
#           ('made', 'fundamental'): 1,
#           ('fundamental', 'change'): 1,
#           ('change', 'business'): 1,
#           ('business', 'selling'): 1,
#           ('selling', 'mobile'): 1,
#           ('mobile', 'phone'): 1,
#           ('phone', 'bustling'): 1,
#           ('bustling', 'street'): 1,
#           ('street', 'market'): 1,
#           ('market', 'lagos'): 1,
#           ('lagos', 'started'): 1,
#           ('started', 'paying'): 1,
#           ('paying', 'supplier'): 1,
#           ('supplier', 'bitco'): 1,
#           ('bitco', 'char'): 1}),
#  Counter({('lagoslondon', 'reuters'): 1,
#           ('reuters', 'four'): 1,
#           ('four', 'month'): 1,
#           ('month', 'ago'): 1,
#           ('ago', 'abolaji'): 1,
#           ('abolaji', 'odunjo'): 1,
#           ('odunjo', 'made'): 1,
#           ('made', 'fundamental'): 1,
#           ('fundamental', 'change'): 1,
#           ('change', 'business'): 1,
#           ('business', 'selling'): 1,
#           ('selling', 'mobile'): 1,
#           ('mobile', 'phone'): 1,
#           ('phone', 'bustling'): 1,
#           ('bustling', 'street'): 1,
#           ('street', 'market'): 1,
#           ('market', 'lagos'): 1,
#           ('lagos', 'started'): 1,
#           ('started', 'paying'): 1,
#           ('paying', 'supplier'): 1,
#           ('supplier', 'bitco'): 1,
#           ('bitco', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('ftx', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'exchange'): 1,
#           ('exchange', 'offer'): 1,
#           ('offer', 'derivative'): 1,
#           ('derivative', 'option'): 1,
#           ('option', 'sophisticated'): 1,
#           ('sophisticated', 'product'): 1,
#           ('product', 'acquiring'): 1,
#           ('acquiring', 'popular'): 1,
#           ('popular', 'portfolio'): 1,
#           ('portfolio', 'tracking'): 1,
#           ('tracking', 'app'): 1,
#           ('app', 'blockfolioftx'): 1,
#           ('blockfolioftx', 'spending'): 1,
#           ('spending', 'million'): 1,
#           ('million', 'acqu'): 1,
#           ('acqu', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('tldr', 'complete'): 1,
#           ('complete', 'stock'): 1,
#           ('stock', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'investment'): 1,
#           ('investment', 'toolkit'): 1,
#           ('toolkit', 'bundle'): 1,
#           ('bundle', 'sale'): 1,
#           ('sale', 'sept'): 1,
#           ('sept', 'saving'): 1,
#           ('saving', 'list'): 1,
#           ('list', 'pricethe'): 1,
#           ('pricethe', 'world'): 1,
#           ('world', 'finance'): 1,
#           ('finance', 'ha'): 1,
#           ('ha', 'always'): 1,
#           ('always', 'complicated'): 1,
#           ('complicated', 'th'): 1,
#           ('th', 'char'): 1}),
#  Counter({('september', 'min'): 1,
#           ('min', 'readopinions'): 1,
#           ('readopinions', 'expressed'): 1,
#           ('expressed', 'entrepreneur'): 1,
#           ('entrepreneur', 'contributor'): 1,
#           ('contributor', 'ownfounded'): 1,
#           ('ownfounded', 'five'): 1,
#           ('five', 'year'): 1,
#           ('year', 'ago'): 1,
#           ('ago', 'ethereum'): 1,
#           ('ethereum', 'platform'): 1,
#           ('platform', 'native'): 1,
#           ('native', 'ether'): 1,
#           ('ether', 'ethhave'): 1,
#           ('ethhave', 'existed'): 1,
#           ('existed', 'mostly'): 1,
#           ('mostly', 'char'): 1}),
#  Counter({('outspoken', 'bitcoin'): 1,
#           ('bitcoin', 'whale'): 1,
#           ('whale', 'rarely'): 1,
#           ('rarely', 'show'): 1,
#           ('show', 'affection'): 1,
#           ('affection', 'anything'): 1,
#           ('anything', 'btc'): 1,
#           ('btc', 'say'): 1,
#           ('say', 'two'): 1,
#           ('two', 'crypto'): 1,
#           ('crypto', 'asset'): 1,
#           ('asset', 'potentialthe'): 1,
#           ('potentialthe', 'pseudonymous'): 1,
#           ('pseudonymous', 'trader'): 1,
#           ('trader', 'known'): 1,
#           ('known', 'joe'): 1,
#           ('joe', 'say'): 1,
#           ('say', 'unus'): 1,
#           ('unus', 'sed'): 1,
#           ('sed', 'leo'): 1,
#           ('leo', 'leo'): 1,
#           ('leo', 'may'): 1,
#           ('may', 'solo'): 1,
#           ('solo', 'char'): 1}),
#  Counter({('youre', 'mac'): 1,
#           ('mac', 'developer'): 1,
#           ('developer', 'like'): 1,
#           ('like', 'try'): 1,
#           ('try', 'new'): 1,
#           ('new', 'apps'): 1,
#           ('apps', 'building'): 1,
#           ('building', 'xcode'): 1,
#           ('xcode', 'project'): 1,
#           ('project', 'serious'): 1,
#           ('serious', 'strain'): 1,
#           ('strain', 'malware'): 1,
#           ('malware', 'need'): 1,
#           ('need', 'aware'): 1,
#           ('aware', 'xcssetcybersecurity'): 1,
#           ('xcssetcybersecurity', 'firm'): 1,
#           ('firm', 'trend'): 1,
#           ('trend', 'micro'): 1,
#           ('micro', 'published'): 1,
#           ('published', 'r'): 1,
#           ('r', 'char'): 1}),
#  Counter({('gold', 'oil'): 1,
#           ('oil', 'historically'): 1,
#           ('historically', 'reliable'): 1,
#           ('reliable', 'store'): 1,
#           ('store', 'value'): 1,
#           ('value', 'scarce'): 1,
#           ('scarce', 'commodity'): 1,
#           ('commodity', 'make'): 1,
#           ('make', 'dependable'): 1,
#           ('dependable', 'hedge'): 1,
#           ('hedge', 'inflation'): 1,
#           ('inflation', 'fiat'): 1,
#           ('fiat', 'currency'): 1,
#           ('currency', 'result'): 1,
#           ('result', 'commanded'): 1,
#           ('commanded', 'pr'): 1,
#           ('pr', 'char'): 1}),
#  Counter({('canton', 'bill'): 1,
#           ('bill', 'home'): 1,
#           ('home', 'crypto'): 1,
#           ('crypto', 'valley'): 1,
#           ('valley', 'said'): 1,
#           ('said', 'would'): 1,
#           ('would', 'accept'): 1,
#           ('accept', 'tax'): 1,
#           ('tax', 'company'): 1,
#           ('company', 'individual'): 1,
#           ('individual', 'swiss'): 1,
#           ('swiss', 'franc'): 1,
#           ('franc', 'paid'): 1,
#           ('paid', 'bitcoin'): 1,
#           ('bitcoin', 'ether'): 1,
#           ('ether', 'fe'): 1,
#           ('fe', 'char'): 1}),
#  Counter({('exuber', 'exec'): 1,
#           ('exec', 'joe'): 1,
#           ('joe', 'sullivan'): 1,
#           ('sullivan', 'coverup'): 1,
#           ('coverup', 'wasnt'): 1,
#           ('wasnt', 'worse'): 1,
#           ('worse', 'crime'): 1,
#           ('crime', 'wa'): 1,
#           ('wa', 'crimeor'): 1,
#           ('crimeor', 'least'): 1,
#           ('least', 'alleges'): 1,
#           ('alleges', 'us'): 1,
#           ('us', 'government'): 1,
#           ('government', 'united'): 1,
#           ('united', 'states'): 1,
#           ('states', 'district'): 1,
#           ('district', 'court'): 1,
#           ('court', 'northern'): 1,
#           ('northern', 'district'): 1,
#           ('district', 'char'): 1}),
#  Counter({('ceo', 'elon'): 1,
#           ('elon', 'musk'): 1,
#           ('musk', 'called'): 1,
#           ('called', 'thwarted'): 1,
#           ('thwarted', 'cyberattack'): 1,
#           ('cyberattack', 'tesla'): 1,
#           ('tesla', 'serious'): 1,
#           ('serious', 'thursday'): 1,
#           ('thursday', 'russian'): 1,
#           ('russian', 'national'): 1,
#           ('national', 'reportedly'): 1,
#           ('reportedly', 'tried'): 1,
#           ('tried', 'recruit'): 1,
#           ('recruit', 'bribe'): 1,
#           ('bribe', 'employee'): 1,
#           ('employee', 'install'): 1,
#           ('install', 'ransomware'): 1,
#           ('ransomware', 'company'): 1,
#           ('company', 'network'): 1,
#           ('network', 'char'): 1}),
#  Counter({('almaty', 'sept'): 1,
#           ('sept', 'reuters'): 1,
#           ('reuters', 'kazakhstan'): 1,
#           ('kazakhstan', 'talk'): 1,
#           ('talk', 'attract'): 1,
#           ('attract', 'investment'): 1,
#           ('investment', 'worth'): 1,
#           ('worth', 'billion'): 1,
#           ('billion', 'tenge'): 1,
#           ('tenge', 'million'): 1,
#           ('million', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'sector'): 1,
#           ('sector', 'digital'): 1,
#           ('digital', 'development'): 1,
#           ('development', 'minister'): 1,
#           ('minister', 'bagdat'): 1,
#           ('bagdat', 'mussin'): 1,
#           ('mussin', 'said'): 1,
#           ('said', 'wedn'): 1,
#           ('wedn', 'char'): 1}),
#  Counter({('lincolnshire', 'sheep'): 1,
#           ('sheep', 'farmer'): 1,
#           ('farmer', 'ha'): 1,
#           ('ha', 'convicted'): 1,
#           ('convicted', 'two'): 1,
#           ('two', 'count'): 1,
#           ('count', 'contaminating'): 1,
#           ('contaminating', 'food'): 1,
#           ('food', 'placing'): 1,
#           ('placing', 'three'): 1,
#           ('three', 'jar'): 1,
#           ('jar', 'baby'): 1,
#           ('baby', 'food'): 1,
#           ('food', 'laced'): 1,
#           ('laced', 'shard'): 1,
#           ('shard', 'metal'): 1,
#           ('metal', 'two'): 1,
#           ('two', 'tesco'): 1,
#           ('tesco', 'storesnigel'): 1,
#           ('storesnigel', 'wright'): 1,
#           ('wright', 'market'): 1,
#           ('market', 'rasen'): 1,
#           ('rasen', 'char'): 1}),
#  Counter({('reuters', 'stafffile'): 1,
#           ('stafffile', 'photo'): 1,
#           ('photo', 'logo'): 1,
#           ('logo', 'binance'): 1,
#           ('binance', 'seen'): 1,
#           ('seen', 'exhibition'): 1,
#           ('exhibition', 'stand'): 1,
#           ('stand', 'delta'): 1,
#           ('delta', 'summit'): 1,
#           ('summit', 'maltas'): 1,
#           ('maltas', 'official'): 1,
#           ('official', 'blockchain'): 1,
#           ('blockchain', 'digital'): 1,
#           ('digital', 'innovation'): 1,
#           ('innovation', 'event'): 1,
#           ('event', 'promoting'): 1,
#           ('promoting', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'ta'): 1,
#           ('ta', 'qali'): 1,
#           ('qali', 'char'): 1}),
#  Counter({('reuters', 'stafffile'): 1,
#           ('stafffile', 'photo'): 1,
#           ('photo', 'silhouette'): 1,
#           ('silhouette', 'mobile'): 1,
#           ('mobile', 'device'): 1,
#           ('device', 'user'): 1,
#           ('user', 'seen'): 1,
#           ('seen', 'next'): 1,
#           ('next', 'screen'): 1,
#           ('screen', 'projection'): 1,
#           ('projection', 'binary'): 1,
#           ('binary', 'code'): 1,
#           ('code', 'seen'): 1,
#           ('seen', 'picture'): 1,
#           ('picture', 'illustration'): 1,
#           ('illustration', 'taken'): 1,
#           ('taken', 'march'): 1,
#           ('march', 'reutersdado'): 1,
#           ('reutersdado', 'ruvicillust'): 1,
#           ('ruvicillust', 'char'): 1}),
#  Counter({('bangkok', 'reuters'): 1,
#           ('reuters', 'hospitals'): 1,
#           ('hospitals', 'company'): 1,
#           ('company', 'thailand'): 1,
#           ('thailand', 'hit'): 1,
#           ('hit', 'hacker'): 1,
#           ('hacker', 'held'): 1,
#           ('held', 'computer'): 1,
#           ('computer', 'system'): 1,
#           ('system', 'data'): 1,
#           ('data', 'ransom'): 1,
#           ('ransom', 'demanding'): 1,
#           ('demanding', 'payment'): 1,
#           ('payment', 'restore'): 1,
#           ('restore', 'information'): 1,
#           ('information', 'police'): 1,
#           ('police', 'said'): 1,
#           ('said', 'thursday'): 1,
#           ('thursday', 'gove'): 1,
#           ('gove', 'char'): 1}),
#  Counter({('least', 'year'): 1,
#           ('year', 'hacker'): 1,
#           ('hacker', 'passing'): 1,
#           ('passing', 'around'): 1,
#           ('around', 'trying'): 1,
#           ('trying', 'break'): 1,
#           ('break', 'bitcoin'): 1,
#           ('bitcoin', 'wallet'): 1,
#           ('wallet', 'potentially'): 1,
#           ('potentially', 'hold'): 1,
#           ('hold', 'around'): 1,
#           ('around', 'million'): 1,
#           ('million', 'btc'): 1,
#           ('btc', 'would'): 1,
#           ('would', 'wallet'): 1,
#           ('wallet', 'seventh'): 1,
#           ('seventh', 'hi'): 1,
#           ('hi', 'char'): 1}),
#  Counter({('washington', 'reuters'): 1,
#           ('reuters', 'former'): 1,
#           ('former', 'chief'): 1,
#           ('chief', 'security'): 1,
#           ('security', 'officer'): 1,
#           ('officer', 'uber'): 1,
#           ('uber', 'technologies'): 1,
#           ('technologies', 'wa'): 1,
#           ('wa', 'criminally'): 1,
#           ('criminally', 'charged'): 1,
#           ('charged', 'thursday'): 1,
#           ('thursday', 'trying'): 1,
#           ('trying', 'cover'): 1,
#           ('cover', 'hacking'): 1,
#           ('hacking', 'exposed'): 1,
#           ('exposed', 'personal'): 1,
#           ('personal', 'information'): 1,
#           ('information', 'mi'): 1,
#           ('mi', 'char'): 1}),
#  Counter({('reuters', 'us'): 1,
#           ('us', 'government'): 1,
#           ('government', 'sought'): 1,
#           ('sought', 'thursday'): 1,
#           ('thursday', 'seize'): 1,
#           ('seize', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'account'): 1,
#           ('account', 'said'): 1,
#           ('said', 'used'): 1,
#           ('used', 'north'): 1,
#           ('north', 'korean'): 1,
#           ('korean', 'hacker'): 1,
#           ('hacker', 'stole'): 1,
#           ('stole', 'million'): 1,
#           ('million', 'dollar'): 1,
#           ('dollar', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'two'): 1,
#           ('two', 'virtual'): 1,
#           ('virtual', 'exch'): 1,
#           ('exch', 'char'): 1}),
#  Counter({('reuters', 'us'): 1,
#           ('us', 'government'): 1,
#           ('government', 'sought'): 1,
#           ('sought', 'thursday'): 1,
#           ('thursday', 'seize'): 1,
#           ('seize', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'account'): 1,
#           ('account', 'said'): 1,
#           ('said', 'used'): 1,
#           ('used', 'north'): 1,
#           ('north', 'korean'): 1,
#           ('korean', 'hacker'): 1,
#           ('hacker', 'stole'): 1,
#           ('stole', 'million'): 1,
#           ('million', 'dollar'): 1,
#           ('dollar', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'two'): 1,
#           ('two', 'virtual'): 1,
#           ('virtual', 'exch'): 1,
#           ('exch', 'char'): 1}),
#  Counter({('despite', 'popularity'): 1,
#           ('popularity', 'among'): 1,
#           ('among', 'drug'): 1,
#           ('drug', 'dealer'): 1,
#           ('dealer', 'dark'): 1,
#           ('dark', 'web'): 1,
#           ('web', 'hacker'): 1,
#           ('hacker', 'demanding'): 1,
#           ('demanding', 'hefty'): 1,
#           ('hefty', 'ransom'): 1,
#           ('ransom', 'unlock'): 1,
#           ('unlock', 'victim'): 1,
#           ('victim', 'computer'): 1,
#           ('computer', 'bitcoin'): 1,
#           ('bitcoin', 'ha'): 1,
#           ('ha', 'never'): 1,
#           ('never', 'hard'): 1,
#           ('hard', 'trace'): 1,
#           ('trace', 'fed'): 1,
#           ('fed', 'cop'): 1,
#           ('cop', 'chasing'): 1,
#           ('chasing', 'sup'): 1,
#           ('sup', 'char'): 1}),
#  Counter({('phone', 'spear'): 1,
#           ('spear', 'phishing'): 1,
#           ('phishing', 'attack'): 1,
#           ('attack', 'rise'): 1,
#           ('rise', 'since'): 1,
#           ('since', 'bitcoin'): 1,
#           ('bitcoin', 'scam'): 1,
#           ('scam', 'took'): 1,
#           ('took', 'social'): 1,
#           ('social', 'medium'): 1,
#           ('medium', 'platform'): 1,
#           ('platform', 'july'): 1,
#           ('july', 'law'): 1,
#           ('law', 'enforcement'): 1,
#           ('enforcement', 'arrested'): 1,
#           ('arrested', 'three'): 1,
#           ('three', 'alleged'): 1,
#           ('alleged', 'young'): 1,
#           ('young', 'hacker'): 1,
#           ('hacker', 'us'): 1,
#           ('us', 'uk'): 1,
#           ('uk', 'la'): 1,
#           ('la', 'char'): 1}),
#  Counter({('sjoerd', 'knibbeler'): 1,
#           ('knibbeler', 'made'): 1,
#           ('made', 'image'): 1,
#           ('image', 'correspondent'): 1,
#           ('correspondent', 'rest'): 1,
#           ('rest', 'image'): 1,
#           ('image', 'piece'): 1,
#           ('piece', 'series'): 1,
#           ('series', 'current'): 1,
#           ('current', 'studies'): 1,
#           ('studies', 'read'): 1,
#           ('read', 'end'): 1,
#           ('end', 'article'): 1,
#           ('article', 'char'): 1}),
#  Counter({('federal', 'authority'): 1,
#           ('authority', 'homed'): 1,
#           ('homed', 'yearold'): 1,
#           ('yearold', 'massachusetts'): 1,
#           ('massachusetts', 'allegedly'): 1,
#           ('allegedly', 'played'): 1,
#           ('played', 'significant'): 1,
#           ('significant', 'role'): 1,
#           ('role', 'july'): 1,
#           ('july', 'twitter'): 1,
#           ('twitter', 'hackback'): 1,
#           ('hackback', 'july'): 1,
#           ('july', 'authority'): 1,
#           ('authority', 'arrested'): 1,
#           ('arrested', 'yearold'): 1,
#           ('yearold', 'graham'): 1,
#           ('graham', 'clark'): 1,
#           ('clark', 'char'): 1}),
#  Counter({('sept', 'reuters'): 1,
#           ('reuters', 'every'): 1,
#           ('every', 'week'): 1,
#           ('week', 'reuters'): 1,
#           ('reuters', 'journalist'): 1,
#           ('journalist', 'produce'): 1,
#           ('produce', 'score'): 1,
#           ('score', 'multimedia'): 1,
#           ('multimedia', 'feature'): 1,
#           ('feature', 'humaninterest'): 1,
#           ('humaninterest', 'story'): 1,
#           ('story', 'around'): 1,
#           ('around', 'world'): 1,
#           ('world', 'engaging'): 1,
#           ('engaging', 'story'): 1,
#           ('story', 'selected'): 1,
#           ('selected', 'editor'): 1,
#           ('editor', 'char'): 1}),
#  Counter({('addition', 'obstruction'): 1,
#           ('obstruction', 'justice'): 1,
#           ('justice', 'prosecutor'): 1,
#           ('prosecutor', 'charged'): 1,
#           ('charged', 'sullivan'): 1,
#           ('sullivan', 'failing'): 1,
#           ('failing', 'share'): 1,
#           ('share', 'knowledge'): 1,
#           ('knowledge', 'felony'): 1,
#           ('felony', 'total'): 1,
#           ('total', 'face'): 1,
#           ('face', 'eight'): 1,
#           ('eight', 'year'): 1,
#           ('year', 'prison'): 1,
#           ('prison', 'convicted'): 1,
#           ('convicted', 'chargeswe'): 1,
#           ('chargeswe', 'exp'): 1,
#           ('exp', 'char'): 1}),
#  Counter({('isolationsite', 'doe'): 1,
#           ('doe', 'one'): 1,
#           ('one', 'thing'): 1,
#           ('thing', 'visit'): 1,
#           ('visit', 'urls'): 1,
#           ('urls', 'want'): 1,
#           ('want', 'check'): 1,
#           ('check', 'dont'): 1,
#           ('dont', 'trust'): 1,
#           ('trust', 'show'): 1,
#           ('show', 'come'): 1,
#           ('come', 'convenient'): 1,
#           ('convenient', 'wrapper'): 1,
#           ('wrapper', 'around'): 1,
#           ('around', 'curl'): 1,
#           ('curl', 'commandline'): 1,
#           ('commandline', 'tool'): 1,
#           ('tool', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('youve', 'bought'): 1,
#           ('bought', 'premium'): 1,
#           ('premium', 'smartphone'): 1,
#           ('smartphone', 'handset'): 1,
#           ('handset', 'past'): 1,
#           ('past', 'year'): 1,
#           ('year', 'safe'): 1,
#           ('safe', 'bet'): 1,
#           ('bet', 'came'): 1,
#           ('came', 'equipped'): 1,
#           ('equipped', 'wireless'): 1,
#           ('wireless', 'charging'): 2,
#           ('charging', 'technology'): 1,
#           ('technology', 'baked'): 1,
#           ('baked', 'wireless'): 1,
#           ('charging', 'wicked'): 1,
#           ('wicked', 'cool'): 1,
#           ('cool', 'char'): 1}),
#  Counter({('jeff', 'royder'): 1,
#           ('royder', 'sr'): 1,
#           ('sr', 'acct'): 1,
#           ('acct', 'mgr'): 1,
#           ('mgr', 'michael'): 1,
#           ('michael', 'scott'): 1,
#           ('scott', 'character'): 1,
#           ('character', 'funny'): 1,
#           ('funny', 'short'): 1,
#           ('short', 'tooreal'): 1,
#           ('tooreal', 'series'): 1,
#           ('series', 'called'): 1,
#           ('called', 'join'): 1,
#           ('join', 'meeting'): 1,
#           ('meeting', 'group'): 1,
#           ('group', 'employee'): 1,
#           ('employee', 'zoom'): 1,
#           ('zoom', 'meeting'): 1,
#           ('meeting', 'five'): 1,
#           ('five', 'episode'): 1,
#           ('episode', 'far'): 1,
#           ('far', 'char'): 1}),
#  Counter({('isolationsite', 'doe'): 1,
#           ('doe', 'one'): 1,
#           ('one', 'thing'): 1,
#           ('thing', 'visit'): 1,
#           ('visit', 'urls'): 1,
#           ('urls', 'want'): 1,
#           ('want', 'check'): 1,
#           ('check', 'dont'): 1,
#           ('dont', 'trust'): 1,
#           ('trust', 'show'): 1,
#           ('show', 'come'): 1,
#           ('come', 'convenient'): 1,
#           ('convenient', 'wrapper'): 1,
#           ('wrapper', 'around'): 1,
#           ('around', 'curl'): 1,
#           ('curl', 'commandline'): 1,
#           ('commandline', 'tool'): 1,
#           ('tool', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('youve', 'bought'): 1,
#           ('bought', 'premium'): 1,
#           ('premium', 'smartphone'): 1,
#           ('smartphone', 'handset'): 1,
#           ('handset', 'past'): 1,
#           ('past', 'year'): 1,
#           ('year', 'safe'): 1,
#           ('safe', 'bet'): 1,
#           ('bet', 'came'): 1,
#           ('came', 'equipped'): 1,
#           ('equipped', 'wireless'): 1,
#           ('wireless', 'charging'): 2,
#           ('charging', 'technology'): 1,
#           ('technology', 'baked'): 1,
#           ('baked', 'wireless'): 1,
#           ('charging', 'wicked'): 1,
#           ('wicked', 'cool'): 1,
#           ('cool', 'char'): 1}),
#  Counter({('isolationsite', 'doe'): 1,
#           ('doe', 'one'): 1,
#           ('one', 'thing'): 1,
#           ('thing', 'visit'): 1,
#           ('visit', 'urls'): 1,
#           ('urls', 'want'): 1,
#           ('want', 'check'): 1,
#           ('check', 'dont'): 1,
#           ('dont', 'trust'): 1,
#           ('trust', 'show'): 1,
#           ('show', 'come'): 1,
#           ('come', 'convenient'): 1,
#           ('convenient', 'wrapper'): 1,
#           ('wrapper', 'around'): 1,
#           ('around', 'curl'): 1,
#           ('curl', 'commandline'): 1,
#           ('commandline', 'tool'): 1,
#           ('tool', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('isolationsite', 'doe'): 1,
#           ('doe', 'one'): 1,
#           ('one', 'thing'): 1,
#           ('thing', 'visit'): 1,
#           ('visit', 'urls'): 1,
#           ('urls', 'want'): 1,
#           ('want', 'check'): 1,
#           ('check', 'dont'): 1,
#           ('dont', 'trust'): 1,
#           ('trust', 'show'): 1,
#           ('show', 'come'): 1,
#           ('come', 'convenient'): 1,
#           ('convenient', 'wrapper'): 1,
#           ('wrapper', 'around'): 1,
#           ('around', 'curl'): 1,
#           ('curl', 'commandline'): 1,
#           ('commandline', 'tool'): 1,
#           ('tool', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('million', 'blockchain'): 1,
#           ('blockchain', 'startup'): 1,
#           ('startup', 'brd'): 1,
#           ('brd', 'rolled'): 1,
#           ('rolled', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'tool'): 1,
#           ('tool', 'partnership'): 1,
#           ('partnership', 'used'): 1,
#           ('used', 'deloitte'): 1,
#           ('deloitte', 'kpmg'): 1,
#           ('kpmg', 'fidelity'): 1,
#           ('fidelity', 'part'): 1,
#           ('part', 'mission'): 1,
#           ('mission', 'make'): 1,
#           ('make', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'accessible'): 1,
#           ('accessible', 'milli'): 1,
#           ('milli', 'char'): 1}),
#  Counter({('yet', 'another'): 1,
#           ('another', 'individual'): 1,
#           ('individual', 'associated'): 1,
#           ('associated', 'notorious'): 1,
#           ('notorious', 'dark'): 1,
#           ('dark', 'web'): 1,
#           ('web', 'marketplace'): 1,
#           ('marketplace', 'alphabay'): 1,
#           ('alphabay', 'going'): 1,
#           ('going', 'jailbryan'): 1,
#           ('jailbryan', 'connor'): 1,
#           ('connor', 'herrell'): 1,
#           ('herrell', 'served'): 1,
#           ('served', 'moderatorhas'): 1,
#           ('moderatorhas', 'sentenced'): 1,
#           ('sentenced', 'year'): 1,
#           ('year', 'prison'): 1,
#           ('prison', 'us'): 1,
#           ('us', 'depa'): 1,
#           ('depa', 'char'): 1}),
#  Counter({('wee', 'hour'): 1,
#           ('hour', 'morning'): 1,
#           ('morning', 'bunch'): 1,
#           ('bunch', 'attacker'): 1,
#           ('attacker', 'identifying'): 1,
#           ('identifying', 'john'): 1,
#           ('john', 'wick'): 1,
#           ('wick', 'took'): 1,
#           ('took', 'overa'): 1,
#           ('overa', 'twitter'): 1,
#           ('twitter', 'accountlinked'): 1,
#           ('accountlinked', 'indian'): 1,
#           ('indian', 'prime'): 1,
#           ('prime', 'minister'): 1,
#           ('minister', 'narendra'): 1,
#           ('narendra', 'modis'): 1,
#           ('modis', 'website'): 1,
#           ('website', 'account'): 1,
#           ('account', 'char'): 1}),
#  Counter({('ullithe', 'us'): 1,
#           ('us', 'dollar'): 1,
#           ('dollar', 'index'): 1,
#           ('index', 'fell'): 1,
#           ('fell', 'lowest'): 1,
#           ('lowest', 'level'): 1,
#           ('level', 'since'): 1,
#           ('since', 'may'): 1,
#           ('may', 'tuesday'): 1,
#           ('tuesday', 'investor'): 1,
#           ('investor', 'grew'): 1,
#           ('grew', 'bearish'): 1,
#           ('bearish', 'toward'): 1,
#           ('toward', 'currencylilithe'): 1,
#           ('currencylilithe', 'gauge'): 1,
#           ('gauge', 'ha'): 1,
#           ('ha', 'dropped'): 1,
#           ('dropped', 'five'): 1,
#           ('five', 'day'): 1,
#           ('day', 'straight'): 1,
#           ('straight', 'amid'): 1,
#           ('amid', 'continued'): 1,
#           ('continued', 'char'): 1}),
#  Counter({('subscribe', 'biweekly'): 1,
#           ('biweekly', 'newsletter'): 2,
#           ('newsletter', 'herewelcome'): 1,
#           ('herewelcome', 'latest'): 1,
#           ('latest', 'edition'): 1,
#           ('edition', 'pardon'): 1,
#           ('pardon', 'intrusion'): 1,
#           ('intrusion', 'tnws'): 1,
#           ('tnws', 'biweekly'): 1,
#           ('newsletter', 'explore'): 1,
#           ('explore', 'wild'): 1,
#           ('wild', 'world'): 1,
#           ('world', 'securityransomware'): 1,
#           ('securityransomware', 'quickly'): 1,
#           ('quickly', 'char'): 1}),
#  Counter({('london', 'reuters'): 1,
#           ('reuters', 'sound'): 1,
#           ('sound', 'like'): 1,
#           ('like', 'surefire'): 1,
#           ('surefire', 'bet'): 1,
#           ('bet', 'lend'): 1,
#           ('lend', 'money'): 1,
#           ('money', 'borrower'): 1,
#           ('borrower', 'put'): 1,
#           ('put', 'collateral'): 1,
#           ('collateral', 'exceeds'): 1,
#           ('exceeds', 'size'): 1,
#           ('size', 'loan'): 1,
#           ('loan', 'earn'): 1,
#           ('earn', 'interest'): 1,
#           ('interest', 'could'): 1,
#           ('could', 'possibly'): 1,
#           ('possibly', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('youve', 'bought'): 1,
#           ('bought', 'premium'): 1,
#           ('premium', 'smartphone'): 1,
#           ('smartphone', 'handset'): 1,
#           ('handset', 'past'): 1,
#           ('past', 'year'): 1,
#           ('year', 'safe'): 1,
#           ('safe', 'bet'): 1,
#           ('bet', 'came'): 1,
#           ('came', 'equipped'): 1,
#           ('equipped', 'wireless'): 1,
#           ('wireless', 'charging'): 2,
#           ('charging', 'technology'): 1,
#           ('technology', 'baked'): 1,
#           ('baked', 'wireless'): 1,
#           ('charging', 'wicked'): 1,
#           ('wicked', 'cool'): 1,
#           ('cool', 'char'): 1}),
#  Counter({('isolationsite', 'doe'): 1,
#           ('doe', 'one'): 1,
#           ('one', 'thing'): 1,
#           ('thing', 'visit'): 1,
#           ('visit', 'urls'): 1,
#           ('urls', 'want'): 1,
#           ('want', 'check'): 1,
#           ('check', 'dont'): 1,
#           ('dont', 'trust'): 1,
#           ('trust', 'show'): 1,
#           ('show', 'come'): 1,
#           ('come', 'convenient'): 1,
#           ('convenient', 'wrapper'): 1,
#           ('wrapper', 'around'): 1,
#           ('around', 'curl'): 1,
#           ('curl', 'commandline'): 1,
#           ('commandline', 'tool'): 1,
#           ('tool', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('nvidia', 'announced'): 1,
#           ('announced', 'sunday'): 1,
#           ('sunday', 'evening'): 1,
#           ('evening', 'ha'): 1,
#           ('ha', 'reached'): 1,
#           ('reached', 'agreement'): 1,
#           ('agreement', 'acquire'): 1,
#           ('acquire', 'arm'): 1,
#           ('arm', 'limited'): 1,
#           ('limited', 'softbank'): 1,
#           ('softbank', 'cool'): 1,
#           ('cool', 'billionin'): 1,
#           ('billionin', 'age'): 1,
#           ('age', 'headline'): 1,
#           ('headline', 'use'): 1,
#           ('use', 'bword'): 1,
#           ('bword', 'place'): 1,
#           ('place', 'nine'): 1,
#           ('nine', 'zero'): 1,
#           ('zero', 'char'): 1}),
#  Counter({('ubers', 'former'): 1,
#           ('former', 'chief'): 1,
#           ('chief', 'securty'): 1,
#           ('securty', 'officer'): 1,
#           ('officer', 'paid'): 1,
#           ('paid', 'two'): 1,
#           ('two', 'hacker'): 1,
#           ('hacker', 'bitcoin'): 1,
#           ('bitcoin', 'bug'): 1,
#           ('bug', 'bounty'): 1,
#           ('bounty', 'reward'): 1,
#           ('reward', 'breached'): 1,
#           ('breached', 'company'): 1,
#           ('company', 'databasesangela'): 1,
#           ('databasesangela', 'langcnetthe'): 1,
#           ('langcnetthe', 'department'): 1,
#           ('department', 'justice'): 1,
#           ('justice', 'ha'): 1,
#           ('ha', 'indicted'): 1,
#           ('indicted', 'char'): 1}),
#  Counter({('hackers', 'breaking'): 1,
#           ('breaking', 'account'): 1,
#           ('account', 'massively'): 1,
#           ('massively', 'popular'): 1,
#           ('popular', 'online'): 1,
#           ('online', 'game'): 1,
#           ('game', 'call'): 1,
#           ('call', 'duty'): 1,
#           ('duty', 'warzone'): 1,
#           ('warzone', 'multiple'): 1,
#           ('multiple', 'victim'): 1,
#           ('victim', 'complain'): 1,
#           ('complain', 'activision'): 1,
#           ('activision', 'publisher'): 1,
#           ('publisher', 'behind'): 1,
#           ('behind', 'game'): 1,
#           ('game', 'slow'): 1,
#           ('slow', 'unresponsive'): 1,
#           ('unresponsive', 'char'): 1}),
#  Counter({('elon', 'musk'): 1,
#           ('musk', 'confirmed'): 1,
#           ('confirmed', 'twitter'): 1,
#           ('twitter', 'thursday'): 1,
#           ('thursday', 'tesla'): 1,
#           ('tesla', 'nevada'): 1,
#           ('nevada', 'factory'): 1,
#           ('factory', 'wa'): 1,
#           ('wa', 'target'): 1,
#           ('target', 'alleged'): 1,
#           ('alleged', 'attempted'): 1,
#           ('attempted', 'cyberattack'): 1,
#           ('cyberattack', 'russian'): 1,
#           ('russian', 'national'): 1,
#           ('national', 'recent'): 1,
#           ('recent', 'weeksa'): 1,
#           ('weeksa', 'russian'): 1,
#           ('russian', 'man'): 1,
#           ('man', 'wasarrested'): 1,
#           ('wasarrested', 'accuse'): 1,
#           ('accuse', 'char'): 1}),
#  Counter({('kid', 'love'): 1,
#           ('love', 'laptop'): 2,
#           ('laptop', 'especially'): 1,
#           ('especially', 'love'): 1,
#           ('laptop', 'play'): 1,
#           ('play', 'minecraft'): 1,
#           ('minecraft', 'let'): 1,
#           ('let', 'watch'): 1,
#           ('watch', 'youtube'): 1,
#           ('youtube', 'hour'): 1,
#           ('hour', 'time'): 1,
#           ('time', 'wondered'): 1,
#           ('wondered', 'would'): 1,
#           ('would', 'like'): 1,
#           ('like', 'laptop'): 1,
#           ('laptop', 'feature'): 1,
#           ('feature', 'foursegment'): 1,
#           ('foursegment', 'led'): 1,
#           ('led', 'displ'): 1,
#           ('displ', 'char'): 1}),
# ...
#           ('jail', 'found'): 1,
#           ('found', 'guilty'): 1,
#           ('guilty', 'attempted'): 1,
#           ('attempted', 'insurance'): 1,
#           ('insurance', 'fraudlilijulija'): 1,
#           ('fraudlilijulija', 'char'): 1}),
#  Counter({('turns', 'plugging'): 1,
#           ('plugging', 'bunch'): 1,
#           ('bunch', 'computer'): 1,
#           ('computer', 'electrical'): 1,
#           ('electrical', 'grid'): 1,
#           ('grid', 'nothing'): 1,
#           ('nothing', 'draw'): 1,
#           ('draw', 'current'): 1,
#           ('current', 'hash'): 1,
#           ('hash', 'algorithm'): 1,
#           ('algorithm', 'ha'): 1,
#           ('ha', 'negative'): 1,
#           ('negative', 'environmental'): 1,
#           ('environmental', 'impact'): 1,
#           ('impact', 'recent'): 1,
#           ('recent', 'study'): 1,
#           ('study', 'suggest'): 1,
#           ('suggest', 'char'): 1}),
#  Counter({('adafruit', 'ha'): 1,
#           ('ha', 'paid'): 1,
#           ('paid', 'day'): 1,
#           ('day', 'voting'): 1,
#           ('voting', 'team'): 1,
#           ('team', 'year'): 1,
#           ('year', 'need'): 1,
#           ('need', 'help'): 1,
#           ('help', 'getting'): 1,
#           ('getting', 'going'): 1,
#           ('going', 'organization'): 1,
#           ('organization', 'let'): 1,
#           ('let', 'u'): 1,
#           ('u', 'know'): 1,
#           ('know', 'share'): 1,
#           ('share', 'well'): 1,
#           ('well', 'good'): 1,
#           ('good', 'resu'): 1,
#           ('resu', 'char'): 1}),
#  Counter({('impeached', 'us'): 1,
#           ('us', 'president'): 1,
#           ('president', 'donald'): 1,
#           ('donald', 'trump'): 1,
#           ('trump', 'wednesday'): 1,
#           ('wednesday', 'demanded'): 1,
#           ('demanded', 'boycott'): 1,
#           ('boycott', 'goodyear'): 1,
#           ('goodyear', 'american'): 1,
#           ('american', 'tire'): 1,
#           ('tire', 'automotive'): 1,
#           ('automotive', 'gear'): 1,
#           ('gear', 'company'): 1,
#           ('company', 'reportedly'): 1,
#           ('reportedly', 'banned'): 1,
#           ('banned', 'red'): 1,
#           ('red', 'maga'): 1,
#           ('maga', 'hat'): 1,
#           ('hat', 'factory'): 1,
#           ('factory', 'floorsdont'): 1,
#           ('floorsdont', 'char'): 1}),
#  Counter({('two', 'tom'): 1,
#           ('tom', 'dancing'): 2,
#           ('dancing', 'bug'): 2,
#           ('bug', 'book'): 1,
#           ('book', 'tom'): 1,
#           ('bug', 'trumpverse'): 1,
#           ('trumpverse', 'superfunpak'): 1,
#           ('superfunpak', 'comix'): 1,
#           ('comix', 'reader'): 1,
#           ('reader', 'available'): 1,
#           ('available', 'information'): 1,
#           ('information', 'book'): 1,
#           ('book', 'including'): 1,
#           ('including', 'order'): 1,
#           ('order', 'special'): 1,
#           ('special', 'char'): 1}),
#  Counter({('get', 'forbes'): 1,
#           ('forbes', 'top'): 1,
#           ('top', 'crypto'): 1,
#           ('crypto', 'blockchain'): 1,
#           ('blockchain', 'storiesdelivered'): 1,
#           ('storiesdelivered', 'inboxevery'): 1,
#           ('inboxevery', 'week'): 1,
#           ('week', 'latest'): 1,
#           ('latest', 'news'): 1,
#           ('news', 'bitcoin'): 1,
#           ('bitcoin', 'major'): 1,
#           ('major', 'cryptocurrencies'): 1,
#           ('cryptocurrencies', 'enterprise'): 1,
#           ('enterprise', 'blockchain'): 1,
#           ('blockchain', 'adoptiongettycrypto'): 1,
#           ('adoptiongettycrypto', 'market'): 1,
#           ('market', 'char'): 1}),
#  Counter({('indians', 'clear'): 1,
#           ('clear', 'favourite'): 1,
#           ('favourite', 'come'): 1,
#           ('come', 'cryptocurrencies'): 1,
#           ('cryptocurrencies', 'world'): 1,
#           ('world', 'largest'): 1,
#           ('largest', 'virtual'): 1,
#           ('virtual', 'currency'): 1,
#           ('currency', 'market'): 1,
#           ('market', 'capitalisationbitcoinis'): 1,
#           ('capitalisationbitcoinis', 'traded'): 1,
#           ('traded', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'indiasince'): 1,
#           ('indiasince', 'march'): 1,
#           ('march', 'char'): 1}),
#  Counter({('woad', 'plant'): 1,
#           ('plant', 'blue'): 1,
#           ('blue', 'dye'): 1,
#           ('dye', 'taken'): 1,
#           ('taken', 'thereof'): 1,
#           ('thereof', 'popularly'): 1,
#           ('popularly', 'associated'): 1,
#           ('associated', 'ironage'): 1,
#           ('ironage', 'britons'): 1,
#           ('britons', 'replaced'): 1,
#           ('replaced', 'superior'): 1,
#           ('superior', 'indigo'): 1,
#           ('indigo', 'plant'): 1,
#           ('plant', 'long'): 1,
#           ('long', 'modern'): 1,
#           ('modern', 'age'): 1,
#           ('age', 'ha'): 1,
#           ('ha', 'fan'): 1,
#           ('fan', 'even'): 1,
#           ('even', 'char'): 1}),
#  Counter({('bitcoin', 'along'): 1,
#           ('along', 'wider'): 1,
#           ('wider', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'market'): 1,
#           ('market', 'ha'): 1,
#           ('ha', 'come'): 1,
#           ('come', 'life'): 1,
#           ('life', 'last'): 1,
#           ('last', 'monthsthe'): 1,
#           ('monthsthe', 'bitcoin'): 1,
#           ('bitcoin', 'price'): 1,
#           ('price', 'crashing'): 1,
#           ('crashing', 'per'): 1,
#           ('per', 'bitcoin'): 1,
#           ('bitcoin', 'broad'): 1,
#           ('broad', 'march'): 1,
#           ('march', 'coronavirus'): 1,
#           ('coronavirus', 'crash'): 1,
#           ('crash', 'ha'): 1,
#           ('ha', 'char'): 1}),
#  Counter({('get', 'forbes'): 1,
#           ('forbes', 'top'): 1,
#           ('top', 'crypto'): 1,
#           ('crypto', 'blockchain'): 1,
#           ('blockchain', 'storiesdelivered'): 1,
#           ('storiesdelivered', 'inboxevery'): 1,
#           ('inboxevery', 'week'): 1,
#           ('week', 'latest'): 1,
#           ('latest', 'news'): 1,
#           ('news', 'bitcoin'): 1,
#           ('bitcoin', 'major'): 1,
#           ('major', 'cryptocurrencies'): 1,
#           ('cryptocurrencies', 'enterprise'): 1,
#           ('enterprise', 'blockchain'): 1,
#           ('blockchain', 'adoptionthe'): 1,
#           ('adoptionthe', 'winklevoss'): 1,
#           ('winklevoss', 'twin'): 1,
#           ('twin', 'char'): 1}),
#  Counter({('uber', 'logo'): 1,
#           ('logo', 'car'): 1,
#           ('car', 'windowubers'): 1,
#           ('windowubers', 'former'): 1,
#           ('former', 'chief'): 1,
#           ('chief', 'security'): 1,
#           ('security', 'officer'): 1,
#           ('officer', 'joseph'): 1,
#           ('joseph', 'sullivan'): 1,
#           ('sullivan', 'ha'): 1,
#           ('ha', 'charged'): 1,
#           ('charged', 'obstruction'): 1,
#           ('obstruction', 'justice'): 1,
#           ('justice', 'usthe'): 1,
#           ('usthe', 'yearold'): 1,
#           ('yearold', 'accused'): 1,
#           ('accused', 'trying'): 1,
#           ('trying', 'cover'): 1,
#           ('cover', 'data'): 1,
#           ('data', 'breach'): 1,
#           ('breach', 'char'): 1}),
#  Counter({('file', 'photo'): 1,
#           ('photo', 'man'): 1,
#           ('man', 'type'): 1,
#           ('type', 'computer'): 1,
#           ('computer', 'keyboard'): 1,
#           ('keyboard', 'illustration'): 1,
#           ('illustration', 'picture'): 1,
#           ('picture', 'february'): 1,
#           ('february', 'reuterskacper'): 1,
#           ('reuterskacper', 'pempelillustrationfile'): 1,
#           ('pempelillustrationfile', 'photofile'): 1,
#           ('photofile', 'photo'): 1,
#           ('photo', 'kacper'): 1,
#           ('kacper', 'pempelreutersprosecutors'): 1,
#           ('pempelreutersprosecutors', 'germany'): 1,
#           ('germany', 'char'): 1}),
#  Counter({('weekend', 'pour'): 1,
#           ('pour', 'mug'): 1,
#           ('mug', 'french'): 1,
#           ('french', 'roast'): 1,
#           ('roast', 'coffee'): 1,
#           ('coffee', 'grab'): 1,
#           ('grab', 'seat'): 1,
#           ('seat', 'swinging'): 1,
#           ('swinging', 'chair'): 1,
#           ('chair', 'get'): 1,
#           ('get', 'ready'): 1,
#           ('ready', 'longer'): 1,
#           ('longer', 'form'): 1,
#           ('form', 'weekend'): 1,
#           ('weekend', 'read'): 1,
#           ('read', 'inside'): 1,
#           ('inside', 'story'): 1,
#           ('story', 'robinhoods'): 1,
#           ('robinhoods', 'billionaire'): 1,
#           ('billionaire', 'found'): 1,
#           ('found', 'char'): 1}),
#  Counter({('last', 'month'): 1,
#           ('month', 'showed'): 1,
#           ('showed', 'bitcoin'): 1,
#           ('bitcoin', 'broke'): 1,
#           ('broke', 'key'): 1,
#           ('key', 'resistance'): 1,
#           ('resistance', 'zone'): 1,
#           ('zone', 'wa'): 1,
#           ('wa', 'sign'): 1,
#           ('sign', 'technical'): 1,
#           ('technical', 'strength'): 1,
#           ('strength', 'since'): 1,
#           ('since', 'bitcoin'): 1,
#           ('bitcoin', 'ha'): 1,
#           ('ha', 'held'): 1,
#           ('held', 'onto'): 1,
#           ('onto', 'gain'): 1,
#           ('gain', 'ha'): 1,
#           ('ha', 'consolidatin'): 1,
#           ('consolidatin', 'char'): 1}),
#  Counter({('bitcoin', 'ha'): 1,
#           ('ha', 'struggled'): 1,
#           ('struggled', 'august'): 1,
#           ('august', 'leaping'): 1,
#           ('leaping', 'higher'): 1,
#           ('higher', 'end'): 1,
#           ('end', 'july'): 1,
#           ('july', 'bitcoin'): 1,
#           ('bitcoin', 'price'): 1,
#           ('price', 'ha'): 1,
#           ('ha', 'repeatedly'): 1,
#           ('repeatedly', 'tried'): 1,
#           ('tried', 'failed'): 1,
#           ('failed', 'gain'): 1,
#           ('gain', 'footing'): 1,
#           ('footing', 'per'): 1,
#           ('per', 'bitcoin'): 1,
#           ('bitcoin', 'currently'): 1,
#           ('currently', 'stuck'): 1,
#           ('stuck', 'tra'): 1,
#           ('tra', 'char'): 1}),
#  Counter({('bitcoin', 'ha'): 1,
#           ('ha', 'declined'): 1,
#           ('declined', 'sharply'): 1,
#           ('sharply', 'week'): 1,
#           ('week', 'losing'): 1,
#           ('losing', 'hour'): 1,
#           ('hour', 'causing'): 1,
#           ('causing', 'trader'): 1,
#           ('trader', 'nervously'): 1,
#           ('nervously', 'eye'): 1,
#           ('eye', 'psychological'): 1,
#           ('psychological', 'per'): 1,
#           ('per', 'bitcoin'): 1,
#           ('bitcoin', 'levelthe'): 1,
#           ('levelthe', 'bitcoin'): 1,
#           ('bitcoin', 'price'): 1,
#           ('price', 'lost'): 1,
#           ('lost', 'matter'): 1,
#           ('matter', 'char'): 1}),
#  Counter({('bitcoin', 'mining'): 2,
#           ('mining', 'big'): 1,
#           ('big', 'business'): 1,
#           ('business', 'ten'): 1,
#           ('ten', 'year'): 1,
#           ('year', 'bitcoin'): 1,
#           ('mining', 'bitcoin'): 1,
#           ('bitcoin', 'token'): 1,
#           ('token', 'rewarded'): 1,
#           ('rewarded', 'maintain'): 1,
#           ('maintain', 'bitcoin'): 1,
#           ('bitcoin', 'network'): 1,
#           ('network', 'ha'): 1,
#           ('ha', 'morphed'): 1,
#           ('morphed', 'bedroombased'): 1,
#           ('bedroombased', 'moneymaking'): 1,
#           ('moneymaking', 'hobby'): 1,
#           ('hobby', 'char'): 1}),
#  Counter({('ethereum', 'long'): 1,
#           ('long', 'played'): 1,
#           ('played', 'second'): 1,
#           ('second', 'fiddle'): 1,
#           ('fiddle', 'number'): 1,
#           ('number', 'one'): 1,
#           ('one', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'bitcoin'): 1,
#           ('bitcoin', 'stepping'): 1,
#           ('stepping', 'limelightthe'): 1,
#           ('limelightthe', 'ethereum'): 1,
#           ('ethereum', 'price'): 1,
#           ('price', 'climbing'): 1,
#           ('climbing', 'last'): 1,
#           ('last', 'hour'): 1,
#           ('hour', 'trading'): 1,
#           ('trading', 'period'): 1,
#           ('period', 'char'): 1}),
#  Counter({('back', 'work'): 1,
#           ('work', 'morning'): 1,
#           ('morning', 'train'): 1,
#           ('train', 'wfh'): 1,
#           ('wfh', 'readsbull'): 1,
#           ('readsbull', 'case'): 1,
#           ('case', 'bear'): 1,
#           ('bear', 'case'): 1,
#           ('case', 'could'): 1,
#           ('could', 'make'): 1,
#           ('make', 'compelling'): 1,
#           ('compelling', 'bull'): 1,
#           ('bull', 'bear'): 1,
#           ('bear', 'care'): 1,
#           ('care', 'every'): 1,
#           ('every', 'asset'): 1,
#           ('asset', 'class'): 1,
#           ('class', 'market'): 1,
#           ('market', 'right'): 1,
#           ('right', 'believe'): 1,
#           ('believe', 'case'): 1,
#           ('case', 'depends'): 1,
#           ('depends', 'char'): 1}),
#  Counter({('reuters', 'us'): 1,
#           ('us', 'government'): 1,
#           ('government', 'sought'): 1,
#           ('sought', 'thursday'): 1,
#           ('thursday', 'seize'): 1,
#           ('seize', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'account'): 1,
#           ('account', 'said'): 1,
#           ('said', 'used'): 1,
#           ('used', 'north'): 1,
#           ('north', 'korean'): 1,
#           ('korean', 'hacker'): 1,
#           ('hacker', 'stole'): 1,
#           ('stole', 'million'): 1,
#           ('million', 'dollar'): 1,
#           ('dollar', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'two'): 1,
#           ('two', 'virtual'): 1,
#           ('virtual', 'exch'): 1,
#           ('exch', 'char'): 1}),
#  Counter({('many', 'u'): 1,
#           ('u', 'covid'): 1,
#           ('covid', 'pandemic'): 1,
#           ('pandemic', 'ha'): 1,
#           ('ha', 'brought'): 1,
#           ('brought', 'u'): 1,
#           ('u', 'closer'): 1,
#           ('closer', 'family'): 1,
#           ('family', 'im'): 1,
#           ('im', 'spending'): 1,
#           ('spending', 'time'): 1,
#           ('time', 'parent'): 1,
#           ('parent', 'quiet'): 1,
#           ('quiet', 'dinner'): 1,
#           ('dinner', 'home'): 1,
#           ('home', 'discussing'): 1,
#           ('discussing', 'state'): 1,
#           ('state', 'world'): 1,
#           ('world', 'wa'): 1,
#           ('wa', 'char'): 1}),
#  Counter({('new', 'york'): 1,
#           ('york', 'city'): 1,
#           ('city', 'ny'): 1,
#           ('ny', 'united'): 1,
#           ('united', 'states'): 1,
#           ('states', 'view'): 1,
#           ('view', 'american'): 1,
#           ('american', 'multinational'): 1,
#           ('multinational', 'financial'): 1,
#           ('financial', 'service'): 1,
#           ('service', 'corporation'): 1,
#           ('corporation', 'fidelity'): 1,
#           ('fidelity', 'investments'): 1,
#           ('investments', 'logo'): 1,
#           ('logo', 'photo'): 1,
#           ('photo', 'alex'): 1,
#           ('alex', 'taisopa'): 1,
#           ('taisopa', 'imageslightrocket'): 1,
#           ('imageslightrocket', 'via'): 1,
#           ('via', 'get'): 1,
#           ('get', 'char'): 1}),
#  Counter({('bitcoin', 'cryptocurrencies'): 1,
#           ('cryptocurrencies', 'exploded'): 1,
#           ('exploded', 'back'): 1,
#           ('back', 'limelight'): 1,
#           ('limelight', 'recent'): 1,
#           ('recent', 'month'): 1,
#           ('month', 'given'): 1,
#           ('given', 'boost'): 1,
#           ('boost', 'federal'): 1,
#           ('federal', 'reserves'): 1,
#           ('reserves', 'coronavirus'): 1,
#           ('coronavirus', 'pandemic'): 1,
#           ('pandemic', 'response'): 1,
#           ('response', 'bitcoin'): 1,
#           ('bitcoin', 'price'): 1,
#           ('price', 'crashing'): 1,
#           ('crashing', 'march'): 1,
#           ('march', 'char'): 1}),
#  Counter({('bitcoin', 'despite'): 1,
#           ('despite', 'growing'): 1,
#           ('growing', 'mainstream'): 1,
#           ('mainstream', 'popularity'): 1,
#           ('popularity', 'favourite'): 1,
#           ('favourite', 'tool'): 1,
#           ('tool', 'cyber'): 1,
#           ('cyber', 'criminal'): 1,
#           ('criminal', 'one'): 1,
#           ('one', 'ransomware'): 1,
#           ('ransomware', 'variant'): 1,
#           ('variant', 'known'): 1,
#           ('known', 'ryuk'): 1,
#           ('ryuk', 'thought'): 1,
#           ('thought', 'stolen'): 1,
#           ('stolen', 'million'): 1,
#           ('million', 'since'): 1,
#           ('since', 'wa'): 1,
#           ('wa', 'created'): 1,
#           ('created', 'char'): 1})]

# %%
# Generate the Ethereum N-grams where N=2
ethereum_ngrams = [Counter(ngrams(i, n=2)) for i in ethereum_df['tokens']]
ethereum_ngrams
# Out:
# [Counter({('youve', 'interacted'): 1,
#           ('interacted', 'cryptocurrencies'): 1,
#           ('cryptocurrencies', 'past'): 1,
#           ('past', 'couple'): 1,
#           ('couple', 'year'): 1,
#           ('year', 'good'): 1,
#           ('good', 'chance'): 1,
#           ('chance', 'youve'): 1,
#           ('youve', 'used'): 1,
#           ('used', 'metamask'): 1,
#           ('metamask', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'wallet'): 1,
#           ('wallet', 'form'): 1,
#           ('form', 'browser'): 1,
#           ('browser', 'extension'): 1,
#           ('extension', 'support'): 1,
#           ('support', 'ether'): 1,
#           ('ether', 'char'): 1}),
#  Counter({('tldr', 'complete'): 1,
#           ('complete', 'stock'): 1,
#           ('stock', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'investment'): 1,
#           ('investment', 'toolkit'): 1,
#           ('toolkit', 'bundle'): 1,
#           ('bundle', 'sale'): 1,
#           ('sale', 'sept'): 1,
#           ('sept', 'saving'): 1,
#           ('saving', 'list'): 1,
#           ('list', 'pricethe'): 1,
#           ('pricethe', 'world'): 1,
#           ('world', 'finance'): 1,
#           ('finance', 'ha'): 1,
#           ('ha', 'always'): 1,
#           ('always', 'complicated'): 1,
#           ('complicated', 'th'): 1,
#           ('th', 'char'): 1}),
#  Counter({('september', 'min'): 1,
#           ('min', 'readopinions'): 1,
#           ('readopinions', 'expressed'): 1,
#           ('expressed', 'entrepreneur'): 1,
#           ('entrepreneur', 'contributor'): 1,
#           ('contributor', 'ownfounded'): 1,
#           ('ownfounded', 'five'): 1,
#           ('five', 'year'): 1,
#           ('year', 'ago'): 1,
#           ('ago', 'ethereum'): 1,
#           ('ethereum', 'platform'): 1,
#           ('platform', 'native'): 1,
#           ('native', 'ether'): 1,
#           ('ether', 'ethhave'): 1,
#           ('ethhave', 'existed'): 1,
#           ('existed', 'mostly'): 1,
#           ('mostly', 'char'): 1}),
#  Counter({('london', 'reuters'): 1,
#           ('reuters', 'sound'): 1,
#           ('sound', 'like'): 1,
#           ('like', 'surefire'): 1,
#           ('surefire', 'bet'): 1,
#           ('bet', 'lend'): 1,
#           ('lend', 'money'): 1,
#           ('money', 'borrower'): 1,
#           ('borrower', 'put'): 1,
#           ('put', 'collateral'): 1,
#           ('collateral', 'exceeds'): 1,
#           ('exceeds', 'size'): 1,
#           ('size', 'loan'): 1,
#           ('loan', 'earn'): 1,
#           ('earn', 'interest'): 1,
#           ('interest', 'could'): 1,
#           ('could', 'possibly'): 1,
#           ('possibly', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('new', 'york'): 1,
#           ('york', 'reuters'): 1,
#           ('reuters', 'brooklynbased'): 1,
#           ('brooklynbased', 'technology'): 1,
#           ('technology', 'startup'): 1,
#           ('startup', 'consensys'): 1,
#           ('consensys', 'ha'): 1,
#           ('ha', 'acquired'): 1,
#           ('acquired', 'jpmorgan'): 1,
#           ('jpmorgan', 'chase'): 1,
#           ('chase', 'amp'): 1,
#           ('amp', 'cos'): 1,
#           ('cos', 'jpmn'): 1,
#           ('jpmn', 'marquee'): 1,
#           ('marquee', 'blockchain'): 1,
#           ('blockchain', 'platform'): 1,
#           ('platform', 'quorum'): 1,
#           ('quorum', 'company'): 1,
#           ('company', 'said'): 1,
#           ('said', 'tuesday'): 1,
#           ('tuesday', 'part'): 1,
#           ('part', 'dea'): 1,
#           ('dea', 'char'): 1}),
#  Counter({('outspoken', 'bitcoin'): 1,
#           ('bitcoin', 'whale'): 1,
#           ('whale', 'rarely'): 1,
#           ('rarely', 'show'): 1,
#           ('show', 'affection'): 1,
#           ('affection', 'anything'): 1,
#           ('anything', 'btc'): 1,
#           ('btc', 'say'): 1,
#           ('say', 'two'): 1,
#           ('two', 'crypto'): 1,
#           ('crypto', 'asset'): 1,
#           ('asset', 'potentialthe'): 1,
#           ('potentialthe', 'pseudonymous'): 1,
#           ('pseudonymous', 'trader'): 1,
#           ('trader', 'known'): 1,
#           ('known', 'joe'): 1,
#           ('joe', 'say'): 1,
#           ('say', 'unus'): 1,
#           ('unus', 'sed'): 1,
#           ('sed', 'leo'): 1,
#           ('leo', 'leo'): 1,
#           ('leo', 'may'): 1,
#           ('may', 'solo'): 1,
#           ('solo', 'char'): 1}),
#  Counter({('tldr', 'training'): 1,
#           ('training', 'interactive'): 1,
#           ('interactive', 'learn'): 1,
#           ('learn', 'code'): 1,
#           ('code', 'bundle'): 1,
#           ('bundle', 'student'): 1,
#           ('student', 'tackle'): 1,
#           ('tackle', 'big'): 1,
#           ('big', 'coding'): 1,
#           ('coding', 'topic'): 1,
#           ('topic', 'handson'): 1,
#           ('handson', 'exercise'): 1,
#           ('exercise', 'help'): 1,
#           ('help', 'learning'): 1,
#           ('learning', 'really'): 1,
#           ('really', 'stickwhile'): 1,
#           ('stickwhile', 'coding'): 1,
#           ('coding', 'simple'): 1,
#           ('simple', 'char'): 1}),
#  Counter({('robot', 'colleague'): 1,
#           ('colleague', 'satoshi'): 1,
#           ('satoshi', 'nakaboto'): 2,
#           ('nakaboto', 'writes'): 1,
#           ('writes', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'every'): 1,
#           ('every', 'fucking'): 1,
#           ('fucking', 'daywelcome'): 1,
#           ('daywelcome', 'another'): 1,
#           ('another', 'edition'): 1,
#           ('edition', 'bitcoin'): 1,
#           ('bitcoin', 'today'): 1,
#           ('today', 'satoshi'): 1,
#           ('nakaboto', 'tell'): 1,
#           ('tell', 'whats'): 1,
#           ('whats', 'going'): 1,
#           ('going', 'bitcoin'): 1,
#           ('bitcoin', 'char'): 1}),
#  Counter({('ethereum', 'long'): 1,
#           ('long', 'played'): 1,
#           ('played', 'second'): 1,
#           ('second', 'fiddle'): 1,
#           ('fiddle', 'number'): 1,
#           ('number', 'one'): 1,
#           ('one', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'bitcoin'): 1,
#           ('bitcoin', 'stepping'): 1,
#           ('stepping', 'limelightthe'): 1,
#           ('limelightthe', 'ethereum'): 1,
#           ('ethereum', 'price'): 1,
#           ('price', 'climbing'): 1,
#           ('climbing', 'last'): 1,
#           ('last', 'hour'): 1,
#           ('hour', 'trading'): 1,
#           ('trading', 'period'): 1,
#           ('period', 'char'): 1}),
#  Counter({('million', 'blockchain'): 1,
#           ('blockchain', 'startup'): 1,
#           ('startup', 'brd'): 1,
#           ('brd', 'rolled'): 1,
#           ('rolled', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'tool'): 1,
#           ('tool', 'partnership'): 1,
#           ('partnership', 'used'): 1,
#           ('used', 'deloitte'): 1,
#           ('deloitte', 'kpmg'): 1,
#           ('kpmg', 'fidelity'): 1,
#           ('fidelity', 'part'): 1,
#           ('part', 'mission'): 1,
#           ('mission', 'make'): 1,
#           ('make', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'accessible'): 1,
#           ('accessible', 'milli'): 1,
#           ('milli', 'char'): 1}),
#  Counter({('ethereum', 'based'): 1,
#           ('based', 'uniswap'): 1,
#           ('uniswap', 'gave'): 1,
#           ('gave', 'uni'): 1,
#           ('uni', 'user'): 1,
#           ('user', 'used'): 1,
#           ('used', 'decentralized'): 1,
#           ('decentralized', 'exchange'): 2,
#           ('exchange', 'prior'): 1,
#           ('prior', 'september'): 1,
#           ('september', 'getty'): 1,
#           ('getty', 'imagesuniswap'): 1,
#           ('imagesuniswap', 'widely'): 1,
#           ('widely', 'utilized'): 1,
#           ('utilized', 'decentralized'): 1,
#           ('exchange', 'ethe'): 1,
#           ('ethe', 'char'): 1}),
#  Counter({('female', 'hand'): 1,
#           ('hand', 'twenty'): 1,
#           ('twenty', 'dollar'): 1,
#           ('dollar', 'white'): 1,
#           ('white', 'backgroundgettysince'): 1,
#           ('backgroundgettysince', 'may'): 1,
#           ('may', 'ethereum'): 1,
#           ('ethereum', 'ha'): 1,
#           ('ha', 'outperformed'): 1,
#           ('outperformed', 'bitcoin'): 1,
#           ('bitcoin', 'largely'): 1,
#           ('largely', 'due'): 1,
#           ('due', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'frenzy'): 1,
#           ('frenzy', 'saw'): 1,
#           ('saw', 'numerous'): 1,
#           ('numerous', 'defi'): 1,
#           ('defi', 'token'): 1,
#           ('token', 'wit'): 1,
#           ('wit', 'char'): 1}),
#  Counter({('poland', 'photo'): 1,
#           ('photo', 'illustration'): 2,
#           ('illustration', 'ethereum'): 1,
#           ('ethereum', 'logo'): 1,
#           ('logo', 'seen'): 1,
#           ('seen', 'displayed'): 1,
#           ('displayed', 'smartphone'): 1,
#           ('smartphone', 'photo'): 1,
#           ('illustration', 'mateusz'): 1,
#           ('mateusz', 'slodkowskisopa'): 1,
#           ('slodkowskisopa', 'imageslightrocket'): 1,
#           ('imageslightrocket', 'via'): 1,
#           ('via', 'getty'): 1,
#           ('getty', 'imagessopa'): 1,
#           ('imagessopa', 'imag'): 1,
#           ('imag', 'char'): 1}),
#  Counter({('price', 'bitcoin'): 2,
#           ('bitcoin', 'look'): 1,
#           ('look', 'enter'): 1,
#           ('enter', 'new'): 1,
#           ('new', 'range'): 1,
#           ('range', 'key'): 1,
#           ('key', 'breakoutsopa'): 1,
#           ('breakoutsopa', 'imageslightrocket'): 1,
#           ('imageslightrocket', 'via'): 1,
#           ('via', 'getty'): 1,
#           ('getty', 'imagesthe'): 1,
#           ('imagesthe', 'price'): 1,
#           ('bitcoin', 'rose'): 1,
#           ('rose', 'high'): 1,
#           ('high', 'coinbase'): 1,
#           ('coinbase', 'ethereum'): 1,
#           ('ethereum', 'eth'): 1,
#           ('eth', 'buoyed'): 1,
#           ('buoyed', 'char'): 1}),
#  Counter({('securities', 'exchange'): 1,
#           ('exchange', 'commission'): 1,
#           ('commission', 'announced'): 1,
#           ('announced', 'settlement'): 1,
#           ('settlement', 'esportsbetting'): 1,
#           ('esportsbetting', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'firm'): 1,
#           ('firm', 'unikrn'): 1,
#           ('unikrn', 'alleged'): 1,
#           ('alleged', 'violation'): 1,
#           ('violation', 'security'): 1,
#           ('security', 'law'): 1,
#           ('law', 'unikrn'): 1,
#           ('unikrn', 'shutter'): 1,
#           ('shutter', 'unikoingold'): 1,
#           ('unikoingold', 'cryptocurr'): 1,
#           ('cryptocurr', 'char'): 1}),
#  Counter({('september', 'min'): 1,
#           ('min', 'readopinions'): 1,
#           ('readopinions', 'expressed'): 1,
#           ('expressed', 'entrepreneur'): 1,
#           ('entrepreneur', 'contributor'): 1,
#           ('contributor', 'ownin'): 1,
#           ('ownin', 'past'): 1,
#           ('past', 'month'): 1,
#           ('month', 'amassive'): 1,
#           ('amassive', 'change'): 1,
#           ('change', 'working'): 1,
#           ('working', 'dynamic'): 1,
#           ('dynamic', 'ha'): 1,
#           ('ha', 'fueled'): 1,
#           ('fueled', 'uptick'): 1,
#           ('uptick', 'kind'): 1,
#           ('kind', 'infecti'): 1,
#           ('infecti', 'char'): 1}),
#  Counter({('billion', 'worth'): 1,
#           ('worth', 'bitcoin'): 1,
#           ('bitcoin', 'ha'): 1,
#           ('ha', 'tokenized'): 1,
#           ('tokenized', 'ethereum'): 1,
#           ('ethereum', 'total'): 1,
#           ('total', 'supply'): 1,
#           ('supply', 'tokenized'): 1,
#           ('tokenized', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'passed'): 1,
#           ('passed', 'thursday'): 1,
#           ('thursday', 'total'): 1,
#           ('total', 'btc'): 1,
#           ('btc', 'supply'): 1,
#           ('supply', 'january'): 1,
#           ('january', 'le'): 1,
#           ('le', 'char'): 1}),
#  Counter({('today', 'team'): 1,
#           ('team', 'behind'): 1,
#           ('behind', 'thebaseline'): 1,
#           ('thebaseline', 'protocolan'): 1,
#           ('protocolan', 'enterprise'): 1,
#           ('enterprise', 'focused'): 1,
#           ('focused', 'blockchain'): 1,
#           ('blockchain', 'project'): 1,
#           ('project', 'pioneered'): 1,
#           ('pioneered', 'bybyey'): 1,
#           ('bybyey', 'microsoft'): 1,
#           ('microsoft', 'consensysamd'): 1,
#           ('consensysamd', 'others'): 1,
#           ('others', 'us'): 1,
#           ('us', 'public'): 1,
#           ('public', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'announced'): 1,
#           ('announced', 'char'): 1}),
#  Counter({('hackproof', 'smart'): 1,
#           ('smart', 'padlock'): 1,
#           ('padlock', 'security'): 1,
#           ('security', 'based'): 1,
#           ('based', 'blockchain'): 1,
#           ('blockchain', 'technology'): 1,
#           ('technology', 'could'): 1,
#           ('could', 'defeated'): 1,
#           ('defeated', 'simple'): 1,
#           ('simple', 'bluetooth'): 1,
#           ('bluetooth', 'replay'): 1,
#           ('replay', 'attack'): 1,
#           ('attack', 'kg'): 1,
#           ('kg', 'lump'): 1,
#           ('lump', 'hammerthe'): 1,
#           ('hammerthe', 'lock'): 1,
#           ('lock', 'technologically'): 1,
#           ('technologically', 'enabled'): 1,
#           ('enabled', 'padlock'): 1,
#           ('padlock', 'char'): 1}),
#  Counter({('learning', 'code'): 1,
#           ('code', 'skill'): 1,
#           ('skill', 'many'): 1,
#           ('many', 'people'): 1,
#           ('people', 'realize'): 1,
#           ('realize', 'take'): 1,
#           ('take', 'time'): 1,
#           ('time', 'understand'): 1,
#           ('understand', 'yet'): 1,
#           ('yet', 'instinctively'): 1,
#           ('instinctively', 'cringe'): 1,
#           ('cringe', 'actual'): 1,
#           ('actual', 'prospect'): 1,
#           ('prospect', 'isnt'): 1,
#           ('isnt', 'hard'): 1,
#           ('hard', 'see'): 1,
#           ('see', 'integral'): 1,
#           ('integral', 'place'): 1,
#           ('place', 'char'): 1}),
#  Counter({('bitcoins', 'price'): 1,
#           ('price', 'mondays'): 1,
#           ('mondays', 'high'): 1,
#           ('high', 'meanwhile'): 1,
#           ('meanwhile', 'high'): 1,
#           ('high', 'fee'): 1,
#           ('fee', 'ethereum'): 1,
#           ('ethereum', 'helped'): 1,
#           ('helped', 'decentralized'): 1,
#           ('decentralized', 'exchange'): 1,
#           ('exchange', 'uniswap'): 1,
#           ('uniswap', 'rake'): 1,
#           ('rake', 'million'): 1,
#           ('million', 'past'): 1,
#           ('past', 'monthullibitcoin'): 1,
#           ('monthullibitcoin', 'btc'): 1,
#           ('btc', 'trading'): 1,
#           ('trading', 'around'): 1,
#           ('around', 'char'): 1}),
#  Counter({('everyone', 'talking'): 1,
#           ('talking', 'capital'): 1,
#           ('capital', 'letter'): 1,
#           ('letter', 'innovation'): 1,
#           ('innovation', 'ar'): 1,
#           ('ar', 'ai'): 1,
#           ('ai', 'iot'): 1,
#           ('iot', 'turned'): 1,
#           ('turned', 'life'): 1,
#           ('life', 'online'): 1,
#           ('online', 'adventure'): 1,
#           ('adventure', 'id'): 1,
#           ('id', 'like'): 1,
#           ('like', 'discus'): 1,
#           ('discus', 'bit'): 1,
#           ('bit', 'prosaic'): 1,
#           ('prosaic', 'still'): 1,
#           ('still', 'promising'): 1,
#           ('promising', 'sphere'): 1,
#           ('sphere', 'char'): 1}),
#  Counter({('cybercriminals', 'successfully'): 1,
#           ('successfully', 'plundered'): 1,
#           ('plundered', 'another'): 1,
#           ('another', 'digital'): 1,
#           ('digital', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'exchangeeuropean'): 1,
#           ('exchangeeuropean', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'exchange'): 1,
#           ('exchange', 'eterbase'): 1,
#           ('eterbase', 'week'): 1,
#           ('week', 'disclosed'): 1,
#           ('disclosed', 'massive'): 1,
#           ('massive', 'breach'): 1,
#           ('breach', 'network'): 1,
#           ('network', 'unknown'): 1,
#           ('unknown', 'group'): 1,
#           ('group', 'hack'): 1,
#           ('hack', 'char'): 1}),
#  Counter({('smart', 'contract'): 1,
#           ('contract', 'platform'): 1,
#           ('platform', 'potential'): 1,
#           ('potential', 'impact'): 1,
#           ('impact', 'society'): 1,
#           ('society', 'significantly'): 1,
#           ('significantly', 'ethereum'): 1,
#           ('ethereum', 'ethusd'): 1,
#           ('ethusd', 'currently'): 1,
#           ('currently', 'clear'): 1,
#           ('clear', 'leader'): 1,
#           ('leader', 'space'): 1,
#           ('space', 'although'): 1,
#           ('although', 'competitor'): 1,
#           ('competitor', 'arguably'): 1,
#           ('arguably', 'superio'): 1,
#           ('superio', 'char'): 1}),
#  Counter({('defi', 'short'): 1,
#           ('short', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'umbrella'): 1,
#           ('umbrella', 'term'): 1,
#           ('term', 'variety'): 1,
#           ('variety', 'financial'): 1,
#           ('financial', 'application'): 1,
#           ('application', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'blockchain'): 1,
#           ('blockchain', 'geared'): 1,
#           ('geared', 'toward'): 1,
#           ('toward', 'disrupting'): 1,
#           ('disrupting', 'financial'): 1,
#           ('financial', 'intermediary'): 1,
#           ('intermediary', 'defi'): 1,
#           ('defi', 'draw'): 1,
#           ('draw', 'char'): 1}),
#  Counter({('bitcoin', 'making'): 1,
#           ('making', 'gain'): 1,
#           ('gain', 'monday'): 1,
#           ('monday', 'ethereum'): 1,
#           ('ethereum', 'usage'): 1,
#           ('usage', 'hitting'): 1,
#           ('hitting', 'record'): 1,
#           ('record', 'high'): 1,
#           ('high', 'septemberullibitcoin'): 1,
#           ('septemberullibitcoin', 'btc'): 1,
#           ('btc', 'trading'): 1,
#           ('trading', 'around'): 1,
#           ('around', 'utc'): 1,
#           ('utc', 'pm'): 1,
#           ('pm', 'et'): 1,
#           ('et', 'gaining'): 1,
#           ('gaining', 'previous'): 1,
#           ('previous', 'ho'): 1,
#           ('ho', 'char'): 1}),
#  Counter({('ethereum', 'transaction'): 1,
#           ('transaction', 'fee'): 1,
#           ('fee', 'soared'): 1,
#           ('soared', 'new'): 1,
#           ('new', 'alltime'): 1,
#           ('alltime', 'high'): 1,
#           ('high', 'second'): 1,
#           ('second', 'time'): 1,
#           ('time', 'three'): 1,
#           ('three', 'week'): 1,
#           ('week', 'according'): 1,
#           ('according', 'onchain'): 1,
#           ('onchain', 'data'): 1,
#           ('data', 'analyzed'): 1,
#           ('analyzed', 'coindeskullias'): 1,
#           ('coindeskullias', 'tuesday'): 1,
#           ('tuesday', 'average'): 1,
#           ('average', 'median'): 1,
#           ('median', 'transaction'): 1,
#           ('transaction', 'char'): 1}),
#  Counter({('bitcoin', 'looking'): 1,
#           ('looking', 'bearish'): 1,
#           ('bearish', 'ethereum'): 1,
#           ('ethereum', 'miner'): 1,
#           ('miner', 'reaping'): 1,
#           ('reaping', 'fee'): 1,
#           ('fee', 'revenue'): 1,
#           ('revenue', 'ever'): 1,
#           ('ever', 'beforeullibitcoin'): 1,
#           ('beforeullibitcoin', 'btc'): 1,
#           ('btc', 'trading'): 1,
#           ('trading', 'around'): 1,
#           ('around', 'utc'): 1,
#           ('utc', 'pm'): 1,
#           ('pm', 'et'): 1,
#           ('et', 'slipping'): 1,
#           ('slipping', 'previ'): 1,
#           ('previ', 'char'): 1}),
#  Counter({('bitcoin', 'lost'): 1,
#           ('lost', 'momentum'): 1,
#           ('momentum', 'thursday'): 1,
#           ('thursday', 'defi'): 1,
#           ('defi', 'delirium'): 1,
#           ('delirium', 'push'): 1,
#           ('push', 'fee'): 1,
#           ('fee', 'ethereum'): 1,
#           ('ethereum', 'back'): 1,
#           ('back', 'upullibitcoin'): 1,
#           ('upullibitcoin', 'btc'): 1,
#           ('btc', 'trading'): 1,
#           ('trading', 'around'): 1,
#           ('around', 'utc'): 1,
#           ('utc', 'pm'): 1,
#           ('pm', 'et'): 1,
#           ('et', 'slipping'): 1,
#           ('slipping', 'previous'): 1,
#           ('previous', 'hour'): 1,
#           ('hour', 'char'): 1}),
#  Counter({('ethereum', 'muchanticipated'): 1,
#           ('muchanticipated', 'move'): 1,
#           ('move', 'proofofstake'): 1,
#           ('proofofstake', 'getting'): 1,
#           ('getting', 'closer'): 1,
#           ('closer', 'coindesk'): 1,
#           ('coindesk', 'research'): 1,
#           ('research', 'analyst'): 1,
#           ('analyst', 'christine'): 1,
#           ('christine', 'kim'): 1,
#           ('kim', 'spoke'): 1,
#           ('spoke', 'ben'): 1,
#           ('ben', 'edgington'): 1,
#           ('edgington', 'vijay'): 1,
#           ('vijay', 'michalik'): 1,
#           ('michalik', 'wouldbe'): 1,
#           ('wouldbe', 'validators'): 1,
#           ('validators', 'need'): 1,
#           ('need', 'kno'): 1,
#           ('kno', 'char'): 1}),
#  Counter({('tether', 'ha'): 1,
#           ('ha', 'adopted'): 1,
#           ('adopted', 'ethereum'): 1,
#           ('ethereum', 'scaling'): 1,
#           ('scaling', 'solution'): 1,
#           ('solution', 'omg'): 1,
#           ('omg', 'network'): 2,
#           ('network', 'amidst'): 1,
#           ('amidst', 'record'): 1,
#           ('record', 'demand'): 1,
#           ('demand', 'settlement'): 1,
#           ('settlement', 'space'): 1,
#           ('space', 'world'): 1,
#           ('world', 'computerthe'): 1,
#           ('computerthe', 'integration'): 1,
#           ('integration', 'tether'): 1,
#           ('tether', 'omg'): 1,
#           ('network', 'result'): 1,
#           ('result', 'reduction'): 1,
#           ('reduction', 'char'): 1}),
#  Counter({('us', 'authority'): 1,
#           ('authority', 'today'): 1,
#           ('today', 'announced'): 1,
#           ('announced', 'criminal'): 1,
#           ('criminal', 'charge'): 1,
#           ('charge', 'financial'): 1,
#           ('financial', 'sanction'): 1,
#           ('sanction', 'two'): 1,
#           ('two', 'russian'): 1,
#           ('russian', 'men'): 1,
#           ('men', 'accused'): 1,
#           ('accused', 'stealing'): 1,
#           ('stealing', 'nearly'): 1,
#           ('nearly', 'million'): 1,
#           ('million', 'worth'): 1,
#           ('worth', 'virtual'): 1,
#           ('virtual', 'currency'): 1,
#           ('currency', 'series'): 1,
#           ('series', 'phishing'): 1,
#           ('phishing', 'attack'): 1,
#           ('attack', 'th'): 1,
#           ('th', 'char'): 1}),
#  Counter({('concept', 'defigettydefi'): 1,
#           ('defigettydefi', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'revolution'): 1,
#           ('revolution', 'uprising'): 1,
#           ('uprising', 'implode'): 1,
#           ('implode', 'smallest'): 1,
#           ('smallest', 'hitch'): 1,
#           ('hitch', 'get'): 1,
#           ('get', 'crushed'): 1,
#           ('crushed', 'boot'): 1,
#           ('boot', 'established'): 1,
#           ('established', 'order'): 1,
#           ('order', 'also'): 1,
#           ('also', 'char'): 1}),
#  Counter({('inx', 'gearing'): 1,
#           ('gearing', 'landmark'): 1,
#           ('landmark', 'ipo'): 1,
#           ('ipo', 'billion'): 1,
#           ('billion', 'tether'): 1,
#           ('tether', 'jumped'): 1,
#           ('jumped', 'tron'): 1,
#           ('tron', 'ethereum'): 1,
#           ('ethereum', 'shift'): 1,
#           ('shift', 'bitcoins'): 1,
#           ('bitcoins', 'option'): 1,
#           ('option', 'market'): 1,
#           ('market', 'suggests'): 1,
#           ('suggests', 'bullish'): 1,
#           ('bullish', 'speculation'): 1,
#           ('speculation', 'beginning'): 1,
#           ('beginning', 'easeyoure'): 1,
#           ('easeyoure', 'readingblockchai'): 1,
#           ('readingblockchai', 'char'): 1}),
#  Counter({('baseline', 'protocol'): 1,
#           ('protocol', 'corporates'): 1,
#           ('corporates', 'use'): 1,
#           ('use', 'ethereum'): 1,
#           ('ethereum', 'public'): 1,
#           ('public', 'mainnet'): 1,
#           ('mainnet', 'common'): 1,
#           ('common', 'frame'): 1,
#           ('frame', 'reference'): 1,
#           ('reference', 'among'): 1,
#           ('among', 'different'): 1,
#           ('different', 'system'): 1,
#           ('system', 'record'): 1,
#           ('record', 'ha'): 1,
#           ('ha', 'released'): 1,
#           ('released', 'version'): 1,
#           ('version', 'announced'): 1,
#           ('announced', 'wednesday'): 1,
#           ('wednesday', 'micr'): 1,
#           ('micr', 'char'): 1}),
#  Counter({('quorum', 'enterprise'): 1,
#           ('enterprise', 'blockchain'): 1,
#           ('blockchain', 'platform'): 1,
#           ('platform', 'developed'): 1,
#           ('developed', 'megabank'): 1,
#           ('megabank', 'jpmorgan'): 1,
#           ('jpmorgan', 'chase'): 1,
#           ('chase', 'acquired'): 1,
#           ('acquired', 'consensys'): 1,
#           ('consensys', 'brooklyn'): 1,
#           ('brooklyn', 'nybased'): 1,
#           ('nybased', 'ethereum'): 1,
#           ('ethereum', 'venture'): 1,
#           ('venture', 'studioadditionally'): 1,
#           ('studioadditionally', 'jpmorgan'): 1,
#           ('jpmorgan', 'ha'): 1,
#           ('ha', 'made'): 1,
#           ('made', 'un'): 1,
#           ('un', 'char'): 1}),
#  Counter({('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'credit'): 1,
#           ('credit', 'market'): 1,
#           ('market', 'aave'): 1,
#           ('aave', 'ha'): 1,
#           ('ha', 'pulled'): 1,
#           ('pulled', 'ahead'): 1,
#           ('ahead', 'stablecoin'): 1,
#           ('stablecoin', 'mint'): 1,
#           ('mint', 'makerdao'): 1,
#           ('makerdao', 'title'): 1,
#           ('title', 'collateral'): 1,
#           ('collateral', 'staked'): 1,
#           ('staked', 'ethereum'): 1,
#           ('ethereum', 'according'): 1,
#           ('according', 'defi'): 1,
#           ('defi', 'pulseaave'): 1,
#           ('pulseaave', 'ha'): 1,
#           ('ha', 'billion'): 1,
#           ('billion', 'char'): 1}),
#  Counter({('news', 'came'): 1,
#           ('came', 'last'): 1,
#           ('last', 'month'): 1,
#           ('month', 'us'): 1,
#           ('us', 'office'): 1,
#           ('office', 'comptroller'): 1,
#           ('comptroller', 'currency'): 1,
#           ('currency', 'occ'): 1,
#           ('occ', 'cleared'): 1,
#           ('cleared', 'bank'): 1,
#           ('bank', 'custody'): 1,
#           ('custody', 'crypto'): 1,
#           ('crypto', 'asset'): 1,
#           ('asset', 'may'): 1,
#           ('may', 'remember'): 1,
#           ('remember', 'expressed'): 1,
#           ('expressed', 'surprise'): 1,
#           ('surprise', 'new'): 1,
#           ('new', 'cry'): 1,
#           ('cry', 'char'): 1}),
#  Counter({('bitcoin', 'hovering'): 1,
#           ('hovering', 'tokenized'): 1,
#           ('tokenized', 'form'): 1,
#           ('form', 'ethereum'): 1,
#           ('ethereum', 'transaction'): 1,
#           ('transaction', 'fee'): 1,
#           ('fee', 'crosshairs'): 1,
#           ('crosshairs', 'coindesks'): 1,
#           ('coindesks', 'markets'): 1,
#           ('markets', 'daily'): 1,
#           ('daily', 'back'): 1,
#           ('back', 'latest'): 1,
#           ('latest', 'crypto'): 1,
#           ('crypto', 'news'): 1,
#           ('news', 'roundupfor'): 1,
#           ('roundupfor', 'early'): 1,
#           ('early', 'access'): 1,
#           ('access', 'char'): 1}),
#  Counter({('bitcoin', 'took'): 1,
#           ('took', 'dive'): 1,
#           ('dive', 'wednesday'): 1,
#           ('wednesday', 'ethereum'): 1,
#           ('ethereum', 'miner'): 1,
#           ('miner', 'benefiting'): 1,
#           ('benefiting', 'defiullibitcoin'): 1,
#           ('defiullibitcoin', 'btc'): 1,
#           ('btc', 'trading'): 1,
#           ('trading', 'around'): 1,
#           ('around', 'utc'): 1,
#           ('utc', 'pm'): 1,
#           ('pm', 'et'): 1,
#           ('et', 'slipping'): 1,
#           ('slipping', 'previous'): 1,
#           ('previous', 'hour'): 1,
#           ('hour', 'char'): 1}),
#  Counter({('wasnt', 'long'): 1,
#           ('long', 'ago'): 1,
#           ('ago', 'ethereum'): 1,
#           ('ethereum', 'upgrade'): 1,
#           ('upgrade', 'went'): 1,
#           ('went', 'live'): 1,
#           ('live', 'official'): 1,
#           ('official', 'test'): 1,
#           ('test', 'network'): 1,
#           ('network', 'developers'): 1,
#           ('developers', 'catching'): 1,
#           ('catching', 'missioncritical'): 1,
#           ('missioncritical', 'bug'): 1,
#           ('bug', 'code'): 1,
#           ('code', 'ever'): 1,
#           ('ever', 'sinceformore'): 1,
#           ('sinceformore', 'episodesand'): 1,
#           ('episodesand', 'free'): 1,
#           ('free', 'early'): 1,
#           ('early', 'access'): 1,
#           ('access', 'char'): 1}),
#  Counter({('bitcoin', 'battle'): 1,
#           ('battle', 'establish'): 1,
#           ('establish', 'foothold'): 1,
#           ('foothold', 'k'): 1,
#           ('k', 'defi'): 1,
#           ('defi', 'surging'): 1,
#           ('surging', 'ethereum'): 1,
#           ('ethereum', 'coindesks'): 1,
#           ('coindesks', 'markets'): 1,
#           ('markets', 'daily'): 1,
#           ('daily', 'back'): 1,
#           ('back', 'latest'): 1,
#           ('latest', 'crypto'): 1,
#           ('crypto', 'news'): 1,
#           ('news', 'roundupfor'): 1,
#           ('roundupfor', 'early'): 1,
#           ('early', 'access'): 1,
#           ('access', 'regular'): 1,
#           ('regular', 'noon'): 1,
#           ('noon', 'char'): 1}),
#  Counter({('billion', 'worth'): 1,
#           ('worth', 'bitcoin'): 1,
#           ('bitcoin', 'ethereum'): 1,
#           ('ethereum', 'recordsetting'): 1,
#           ('recordsetting', 'transaction'): 1,
#           ('transaction', 'volume'): 1,
#           ('volume', 'boosting'): 1,
#           ('boosting', 'ethereum'): 1,
#           ('ethereum', 'miner'): 1,
#           ('miner', 'revenue'): 1,
#           ('revenue', 'vechain'): 1,
#           ('vechain', 'join'): 1,
#           ('join', 'chinas'): 1,
#           ('chinas', 'food'): 1,
#           ('food', 'safety'): 1,
#           ('safety', 'watchdog'): 1,
#           ('watchdog', 'build'): 1,
#           ('build', 'track'): 1,
#           ('track', 'char'): 1}),
#  Counter({('floods', 'dampening'): 1,
#           ('dampening', 'bitcoin'): 1,
#           ('bitcoin', 'mining'): 1,
#           ('mining', 'hashrates'): 1,
#           ('hashrates', 'ethereum'): 1,
#           ('ethereum', 'classic'): 1,
#           ('classic', 'may'): 1,
#           ('may', 'thrown'): 1,
#           ('thrown', 'popular'): 1,
#           ('popular', 'exchange'): 1,
#           ('exchange', 'bitcoin'): 1,
#           ('bitcoin', 'moving'): 1,
#           ('moving', 'exchangesyoure'): 1,
#           ('exchangesyoure', 'readingblockchain'): 1,
#           ('readingblockchain', 'bites'): 1,
#           ('bites', 'daily'): 1,
#           ('daily', 'roundup'): 1,
#           ('roundup', 'char'): 1}),
#  Counter({('takeawayulliunder', 'development'): 1,
#           ('development', 'lnpbp'): 1,
#           ('lnpbp', 'standards'): 1,
#           ('standards', 'association'): 1,
#           ('association', 'rgb'): 1,
#           ('rgb', 'protocol'): 1,
#           ('protocol', 'entered'): 1,
#           ('entered', 'beta'): 1,
#           ('beta', 'junelilithe'): 1,
#           ('junelilithe', 'second'): 1,
#           ('second', 'layer'): 1,
#           ('layer', 'network'): 1,
#           ('network', 'promise'): 1,
#           ('promise', 'bring'): 1,
#           ('bring', 'smart'): 1,
#           ('smart', 'contract'): 1,
#           ('contract', 'tokenized'): 1,
#           ('tokenized', 'char'): 1}),
#  Counter({('year', 'debating'): 1,
#           ('debating', 'whether'): 1,
#           ('whether', 'tether'): 1,
#           ('tether', 'usdt'): 1,
#           ('usdt', 'fully'): 1,
#           ('fully', 'backed'): 1,
#           ('backed', 'us'): 1,
#           ('us', 'dollar'): 1,
#           ('dollar', 'stablecoins'): 1,
#           ('stablecoins', 'critic'): 1,
#           ('critic', 'defender'): 1,
#           ('defender', 'alike'): 1,
#           ('alike', 'put'): 1,
#           ('put', 'money'): 1,
#           ('money', 'mouth'): 1,
#           ('mouth', 'areopium'): 1,
#           ('areopium', 'derivati'): 1,
#           ('derivati', 'char'): 1}),
#  Counter({('berlinbased', 'startup'): 1,
#           ('startup', 'creating'): 1,
#           ('creating', 'tech'): 1,
#           ('tech', 'stack'): 1,
#           ('stack', 'automated'): 1,
#           ('automated', 'ethereum'): 1,
#           ('ethereum', 'service'): 1,
#           ('service', 'ha'): 1,
#           ('ha', 'raised'): 1,
#           ('raised', 'million'): 1,
#           ('million', 'seed'): 1,
#           ('seed', 'round'): 1,
#           ('round', 'led'): 1,
#           ('led', 'polkadot'): 1,
#           ('polkadot', 'backer'): 1,
#           ('backer', 'iosg'): 1,
#           ('iosg', 'ventures'): 1,
#           ('ventures', 'crypto'): 1,
#           ('crypto', 'merchant'): 1,
#           ('merchant', 'bank'): 1,
#           ('bank', 'galaxy'): 1,
#           ('galaxy', 'digital'): 1,
#           ('digital', 'char'): 1}),
#  Counter({('number', 'pending'): 1,
#           ('pending', 'transaction'): 1,
#           ('transaction', 'ethereum'): 1,
#           ('ethereum', 'per'): 1,
#           ('per', 'minute'): 1,
#           ('minute', 'ha'): 1,
#           ('ha', 'jumped'): 1,
#           ('jumped', 'claim'): 1,
#           ('claim', 'uniswaps'): 1,
#           ('uniswaps', 'uni'): 1,
#           ('uni', 'token'): 1,
#           ('token', 'beginsthe'): 1,
#           ('beginsthe', 'decentralized'): 1,
#           ('decentralized', 'trading'): 1,
#           ('trading', 'platform'): 1,
#           ('platform', 'announced'): 1,
#           ('announced', 'around'): 1,
#           ('around', 'utc'): 1,
#           ('utc', 'time'): 1,
#           ('time', 'thursday'): 1,
#           ('thursday', 'char'): 1}),
#  Counter({('everyone', 'may'): 1,
#           ('may', 'talking'): 1,
#           ('talking', 'governance'): 1,
#           ('governance', 'ethereum'): 1,
#           ('ethereum', 'yettolaunch'): 1,
#           ('yettolaunch', 'stablecoin'): 1,
#           ('stablecoin', 'startup'): 1,
#           ('startup', 'liquity'): 1,
#           ('liquity', 'taking'): 1,
#           ('taking', 'contrarian'): 1,
#           ('contrarian', 'view'): 1,
#           ('view', 'zero'): 1,
#           ('zero', 'governancethat'): 1,
#           ('governancethat', 'doesnt'): 1,
#           ('doesnt', 'mean'): 1,
#           ('mean', 'wont'): 1,
#           ('wont', 'offer'): 1,
#           ('offer', 'yield'): 1,
#           ('yield', 'farming'): 1,
#           ('farming', 'char'): 1}),
#  Counter({('theres', 'joke'): 1,
#           ('joke', 'world'): 1,
#           ('world', 'digital'): 1,
#           ('digital', 'advertising'): 1,
#           ('advertising', 'many'): 1,
#           ('many', 'company'): 1,
#           ('company', 'doe'): 1,
#           ('doe', 'take'): 1,
#           ('take', 'put'): 1,
#           ('put', 'ad'): 1,
#           ('ad', 'websitein'): 1,
#           ('websitein', 'fact'): 1,
#           ('fact', 'many'): 1,
#           ('many', 'intermediary'): 1,
#           ('intermediary', 'participating'): 1,
#           ('participating', 'opaque'): 1,
#           ('opaque', 'process'): 1,
#           ('process', 'char'): 1}),
#  Counter({('native', 'token'): 1,
#           ('token', 'omg'): 1,
#           ('omg', 'network'): 1,
#           ('network', 'ha'): 1,
#           ('ha', 'doubled'): 1,
#           ('doubled', 'past'): 1,
#           ('past', 'week'): 1,
#           ('week', 'record'): 1,
#           ('record', 'ethereum'): 1,
#           ('ethereum', 'fee'): 1,
#           ('fee', 'lead'): 1,
#           ('lead', 'investor'): 1,
#           ('investor', 'look'): 1,
#           ('look', 'layer'): 1,
#           ('layer', 'solutionsullicoingecko'): 1,
#           ('solutionsullicoingecko', 'data'): 1,
#           ('data', 'show'): 1,
#           ('show', 'omg'): 1,
#           ('omg', 'token'): 1,
#           ('token', 'increas'): 1,
#           ('increas', 'char'): 1}),
#  Counter({('leah', 'callonbutler'): 1,
#           ('callonbutler', 'coindesk'): 1,
#           ('coindesk', 'columnist'): 1,
#           ('columnist', 'director'): 1,
#           ('director', 'emfarsis'): 1,
#           ('emfarsis', 'consulting'): 1,
#           ('consulting', 'firm'): 1,
#           ('firm', 'focused'): 1,
#           ('focused', 'role'): 1,
#           ('role', 'technology'): 1,
#           ('technology', 'advancing'): 1,
#           ('advancing', 'economic'): 1,
#           ('economic', 'development'): 1,
#           ('development', 'asiain'): 1,
#           ('asiain', 'early'): 1,
#           ('early', 'antivideo'): 1,
#           ('antivideo', 'g'): 1,
#           ('g', 'char'): 1}),
#  Counter({('ethereum', 'classics'): 1,
#           ('classics', 'hashrate'): 1,
#           ('hashrate', 'ha'): 1,
#           ('ha', 'dropped'): 1,
#           ('dropped', 'precipitously'): 1,
#           ('precipitously', 'since'): 1,
#           ('since', 'january'): 1,
#           ('january', 'continues'): 1,
#           ('continues', 'decline'): 1,
#           ('decline', 'two'): 1,
#           ('two', 'successful'): 1,
#           ('successful', 'attack'): 1,
#           ('attack', 'network'): 1,
#           ('network', 'earlier'): 1,
#           ('earlier', 'august'): 1,
#           ('august', 'light'): 1,
#           ('light', 'vulnerability'): 1,
#           ('vulnerability', 'ethereum'): 1,
#           ('ethereum', 'char'): 1}),
#  Counter({('cryptos', 'digital'): 1,
#           ('digital', 'dollar'): 1,
#           ('dollar', 'stablecoin'): 1,
#           ('stablecoin', 'volume'): 1,
#           ('volume', 'received'): 1,
#           ('received', 'blockchain'): 1,
#           ('blockchain', 'upgrade'): 1,
#           ('upgrade', 'last'): 1,
#           ('last', 'week'): 1,
#           ('week', 'support'): 1,
#           ('support', 'faster'): 1,
#           ('faster', 'transaction'): 1,
#           ('transaction', 'adding'): 1,
#           ('adding', 'network'): 1,
#           ('network', 'called'): 1,
#           ('called', 'algorand'): 1,
#           ('algorand', 'us'): 1,
#           ('us', 'dollar'): 1,
#           ('dollar', 'coin'): 1,
#           ('coin', 'usdc'): 1,
#           ('usdc', 'symbol'): 1,
#           ('symbol', 'char'): 1}),
#  Counter({('despite', 'three'): 1,
#           ('three', 'attack'): 1,
#           ('attack', 'month'): 1,
#           ('month', 'ethereum'): 1,
#           ('ethereum', 'classics'): 1,
#           ('classics', 'price'): 1,
#           ('price', 'ha'): 1,
#           ('ha', 'demonstrated'): 1,
#           ('demonstrated', 'strong'): 1,
#           ('strong', 'resilience'): 1,
#           ('resilience', 'though'): 1,
#           ('though', 'bit'): 1,
#           ('bit', 'past'): 1,
#           ('past', 'month'): 1,
#           ('month', 'persistence'): 1,
#           ('persistence', 'may'): 1,
#           ('may', 'indicate'): 1,
#           ('indicate', 'security'): 1,
#           ('security', 'top'): 1,
#           ('top', 'priorit'): 1,
#           ('priorit', 'char'): 1}),
#  Counter({('critical', 'bug'): 1,
#           ('bug', 'ha'): 1,
#           ('ha', 'left'): 1,
#           ('left', 'ethereum'): 1,
#           ('ethereum', 'node'): 1,
#           ('node', 'useless'): 1,
#           ('useless', 'highlighting'): 1,
#           ('highlighting', 'growing'): 1,
#           ('growing', 'chink'): 1,
#           ('chink', 'network'): 1,
#           ('network', 'armor'): 1,
#           ('armor', 'client'): 1,
#           ('client', 'centralizationfirst'): 1,
#           ('centralizationfirst', 'hinted'): 1,
#           ('hinted', 'may'): 1,
#           ('may', 'june'): 1,
#           ('june', 'github'): 1,
#           ('github', 'minority'): 1,
#           ('minority', 'client'): 1,
#           ('client', 'char'): 1}),
#  Counter({('explosive', 'growth'): 1,
#           ('growth', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'ha'): 1,
#           ('ha', 'brought'): 1,
#           ('brought', 'unwanted'): 1,
#           ('unwanted', 'attention'): 1,
#           ('attention', 'recent'): 1,
#           ('recent', 'surge'): 1,
#           ('surge', 'congestion'): 1,
#           ('congestion', 'network'): 1,
#           ('network', 'resulting'): 1,
#           ('resulting', 'jump'): 1,
#           ('jump', 'transactio'): 1,
#           ('transactio', 'char'): 1}),
#  Counter({('protocol', 'protocol'): 1,
#           ('protocol', 'polkadot'): 1,
#           ('polkadot', 'network'): 1,
#           ('network', 'week'): 1,
#           ('week', 'away'): 1,
#           ('away', 'release'): 1,
#           ('release', 'first'): 1,
#           ('first', 'viable'): 1,
#           ('viable', 'bridge'): 1,
#           ('bridge', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'according'): 1,
#           ('according', 'today'): 1,
#           ('today', 'announcement'): 1,
#           ('announcement', 'developer'): 1,
#           ('developer', 'house'): 1,
#           ('house', 'snowfork'): 1,
#           ('snowfork', 'bridg'): 1,
#           ('bridg', 'char'): 1}),
#  Counter({('data', 'provider'): 1,
#           ('provider', 'chainlink'): 1,
#           ('chainlink', 'provide'): 1,
#           ('provide', 'decentralized'): 1,
#           ('decentralized', 'weather'): 1,
#           ('weather', 'data'): 1,
#           ('data', 'insurance'): 1,
#           ('insurance', 'startup'): 1,
#           ('startup', 'arbol'): 1,
#           ('arbol', 'according'): 1,
#           ('according', 'blog'): 1,
#           ('blog', 'shared'): 1,
#           ('shared', 'coindeskarbol'): 1,
#           ('coindeskarbol', 'provides'): 1,
#           ('provides', 'crop'): 1,
#           ('crop', 'insurance'): 1,
#           ('insurance', 'small'): 1,
#           ('small', 'medium'): 1,
#           ('medium', 'sized'): 1,
#           ('sized', 'farmer'): 1,
#           ('farmer', 'char'): 1}),
#  Counter({('hopes', 'bottleneck'): 1,
#           ('bottleneck', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'might'): 1,
#           ('might', 'ease'): 1,
#           ('ease', 'sent'): 1,
#           ('sent', 'token'): 1,
#           ('token', 'associated'): 1,
#           ('associated', 'decentralized'): 1,
#           ('decentralized', 'exchange'): 1,
#           ('exchange', 'known'): 1,
#           ('known', 'dex'): 1,
#           ('dex', 'token'): 1,
#           ('token', 'soaring'): 1,
#           ('soaring', 'token'): 1,
#           ('token', 'x'): 1,
#           ('x', 'exchange'): 1,
#           ('exchange', 'zrx'): 1,
#           ('zrx', 'rallying'): 1,
#           ('rallying', 'char'): 1}),
#  Counter({('ethereum', 'smart'): 1,
#           ('smart', 'contract'): 1,
#           ('contract', 'feature'): 1,
#           ('feature', 'offer'): 1,
#           ('offer', 'rebate'): 1,
#           ('rebate', 'fee'): 1,
#           ('fee', 'ha'): 1,
#           ('ha', 'developer'): 1,
#           ('developer', 'scratching'): 1,
#           ('scratching', 'head'): 1,
#           ('head', 'wondering'): 1,
#           ('wondering', 'toss'): 1,
#           ('toss', 'old'): 1,
#           ('old', 'code'): 1,
#           ('code', 'light'): 1,
#           ('light', 'exponential'): 1,
#           ('exponential', 'rise'): 1,
#           ('rise', 'transaction'): 1,
#           ('transaction', 'cost'): 1,
#           ('cost', 'char'): 1}),
#  Counter({('pornhub', 'accept'): 1,
#           ('accept', 'btc'): 1,
#           ('btc', 'ltc'): 1,
#           ('ltc', 'payment'): 1,
#           ('payment', 'nonprofit'): 1,
#           ('nonprofit', 'calling'): 1,
#           ('calling', 'upon'): 1,
#           ('upon', 'coinbase'): 1,
#           ('coinbase', 'transparent'): 1,
#           ('transparent', 'credit'): 1,
#           ('credit', 'default'): 1,
#           ('default', 'swap'): 1,
#           ('swap', 'coming'): 1,
#           ('coming', 'ethereum'): 1,
#           ('ethereum', 'blockchainyoure'): 1,
#           ('blockchainyoure', 'readingblockchain'): 1,
#           ('readingblockchain', 'bites'): 1,
#           ('bites', 'char'): 1}),
#  Counter({('column', 'haswritten'): 1,
#           ('haswritten', 'recent'): 1,
#           ('recent', 'weeksabout'): 1,
#           ('weeksabout', 'surprising'): 1,
#           ('surprising', 'possibility'): 1,
#           ('possibility', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'market'): 1,
#           ('market', 'might'): 1,
#           ('might', 'become'): 1,
#           ('become', 'thenew'): 1,
#           ('thenew', 'home'): 1,
#           ('home', 'capitalism'): 1,
#           ('capitalism', 'environment'): 1,
#           ('environment', 'central'): 1,
#           ('central', 'bank'): 1,
#           ('bank', 'governme'): 1,
#           ('governme', 'char'): 1}),
#  Counter({('hows', 'first'): 1,
#           ('first', 'registered'): 1,
#           ('registered', 'offering'): 1,
#           ('offering', 'security'): 1,
#           ('security', 'token'): 1,
#           ('token', 'us'): 1,
#           ('us', 'going'): 1,
#           ('going', 'see'): 1,
#           ('see', 'yourselfin'): 1,
#           ('yourselfin', 'two'): 1,
#           ('two', 'week'): 1,
#           ('week', 'since'): 1,
#           ('since', 'inx'): 1,
#           ('inx', 'ltd'): 1,
#           ('ltd', 'commenced'): 1,
#           ('commenced', 'longawaited'): 1,
#           ('longawaited', 'initial'): 1,
#           ('initial', 'public'): 1,
#           ('public', 'offering'): 1,
#           ('offering', 'ipo'): 1,
#           ('ipo', 'inv'): 1,
#           ('inv', 'char'): 1}),
#  Counter({('swisscom', 'blockchain'): 1,
#           ('blockchain', 'distributed'): 1,
#           ('distributed', 'ledger'): 1,
#           ('ledger', 'technology'): 1,
#           ('technology', 'startup'): 1,
#           ('startup', 'owned'): 1,
#           ('owned', 'telco'): 1,
#           ('telco', 'giant'): 1,
#           ('giant', 'swisscom'): 1,
#           ('swisscom', 'ha'): 1,
#           ('ha', 'awarded'): 1,
#           ('awarded', 'grant'): 1,
#           ('grant', 'web'): 1,
#           ('web', 'foundation'): 1,
#           ('foundation', 'build'): 1,
#           ('build', 'cloudbased'): 1,
#           ('cloudbased', 'protection'): 1,
#           ('protection', 'layer'): 1,
#           ('layer', 'stakers'): 1,
#           ('stakers', 'th'): 1,
#           ('th', 'char'): 1}),
#  Counter({('security', 'token'): 1,
#           ('token', 'platform'): 1,
#           ('platform', 'tzero'): 1,
#           ('tzero', 'announced'): 1,
#           ('announced', 'thursday'): 1,
#           ('thursday', 'financial'): 1,
#           ('financial', 'industry'): 1,
#           ('industry', 'regulatory'): 1,
#           ('regulatory', 'authority'): 1,
#           ('authority', 'finra'): 1,
#           ('finra', 'ha'): 1,
#           ('ha', 'approved'): 1,
#           ('approved', 'application'): 1,
#           ('application', 'launch'): 1,
#           ('launch', 'retail'): 1,
#           ('retail', 'brokerdealer'): 1,
#           ('brokerdealer', 'subsidiary'): 1,
#           ('subsidiary', 'tzero'): 1,
#           ('tzero', 'marketsa'): 1,
#           ('marketsa', 'major'): 1,
#           ('major', 'char'): 1}),
#  Counter({('researchers', 'zengo'): 1,
#           ('zengo', 'properly'): 1,
#           ('properly', 'disclosed'): 1,
#           ('disclosed', 'vulnerability'): 1,
#           ('vulnerability', 'discovered'): 1,
#           ('discovered', 'diogenes'): 1,
#           ('diogenes', 'protocol'): 1,
#           ('protocol', 'proof'): 1,
#           ('proof', 'proof'): 1,
#           ('proof', 'designed'): 1,
#           ('designed', 'provide'): 1,
#           ('provide', 'raw'): 1,
#           ('raw', 'entropy'): 1,
#           ('entropy', 'verifiable'): 1,
#           ('verifiable', 'delay'): 1,
#           ('delay', 'function'): 1,
#           ('function', 'vdf'): 1,
#           ('vdf', 'char'): 1}),
#  Counter({('isnt', 'cryptokitties'): 1,
#           ('cryptokitties', 'craze'): 1,
#           ('craze', 'situation'): 1,
#           ('situation', 'different'): 1,
#           ('different', 'stefan'): 1,
#           ('stefan', 'george'): 1,
#           ('george', 'gnosis'): 1,
#           ('gnosis', 'told'): 1,
#           ('told', 'coindesk'): 1,
#           ('coindesk', 'lots'): 1,
#           ('lots', 'dapps'): 1,
#           ('dapps', 'clawing'): 1,
#           ('clawing', 'ethereums'): 1,
#           ('ethereums', 'compute'): 1,
#           ('compute', 'power'): 1,
#           ('power', 'activity'): 1,
#           ('activity', 'calm'): 1,
#           ('calm', 'one'): 1,
#           ('one', 'char'): 1}),
#  Counter({('uniswaps', 'governance'): 1,
#           ('governance', 'token'): 1,
#           ('token', 'uni'): 1,
#           ('uni', 'wa'): 1,
#           ('wa', 'launched'): 1,
#           ('launched', 'wednesday'): 1,
#           ('wednesday', 'night'): 1,
#           ('night', 'ha'): 1,
#           ('ha', 'rollercoaster'): 1,
#           ('rollercoaster', 'ride'): 1,
#           ('ride', 'past'): 1,
# ...
#           ('finance', 'defi'): 1,
#           ('defi', 'platform'): 1,
#           ('platform', 'bitcoin'): 1,
#           ('bitcoin', 'btc'): 1,
#           ('btc', 'nonethereum'): 1,
#           ('nonethereum', 'assetsthe'): 1,
#           ('assetsthe', 'product'): 1,
#           ('product', 'called'): 1,
#           ('called', 'harvest'): 1,
#           ('harvest', 'built'): 1,
#           ('built', 'k'): 1,
#           ('k', 'char'): 1}),
#  Counter({('closeup', 'one'): 1,
#           ('one', 'dollar'): 1,
#           ('dollar', 'bill'): 1,
#           ('bill', 'blockchain'): 1,
#           ('blockchain', 'code'): 1,
#           ('code', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'digital'): 1,
#           ('digital', 'money'): 1,
#           ('money', 'conceptgettyif'): 1,
#           ('conceptgettyif', 'studied'): 1,
#           ('studied', 'price'): 1,
#           ('price', 'action'): 1,
#           ('action', 'ignored'): 1,
#           ('ignored', 'background'): 1,
#           ('background', 'noise'): 1,
#           ('noise', 'major'): 1,
#           ('major', 'cryptocur'): 1,
#           ('cryptocur', 'char'): 1}),
#  Counter({('fees', 'transaction'): 1,
#           ('transaction', 'ethereum'): 1,
#           ('ethereum', 'network'): 1,
#           ('network', 'hit'): 1,
#           ('hit', 'new'): 1,
#           ('new', 'alltime'): 1,
#           ('alltime', 'high'): 1,
#           ('high', 'tuesday'): 1,
#           ('tuesday', 'development'): 1,
#           ('development', 'come'): 1,
#           ('come', 'activity'): 1,
#           ('activity', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'ecosystem'): 1,
#           ('ecosystem', 'continues'): 1,
#           ('continues', 'growaccording'): 1,
#           ('growaccording', 'char'): 1}),
#  Counter({('longawaited', 'transition'): 1,
#           ('transition', 'ethereum'): 1,
#           ('ethereum', 'finally'): 1,
#           ('finally', 'approachingdanny'): 1,
#           ('approachingdanny', 'ryan'): 1,
#           ('ryan', 'core'): 1,
#           ('core', 'developer'): 1,
#           ('developer', 'ethereum'): 1,
#           ('ethereum', 'foundation'): 1,
#           ('foundation', 'ha'): 1,
#           ('ha', 'today'): 1,
#           ('today', 'officially'): 1,
#           ('officially', 'submitted'): 1,
#           ('submitted', 'proposal'): 1,
#           ('proposal', 'moving'): 1,
#           ('moving', 'ethereum'): 1,
#           ('ethereum', 'blockc'): 1,
#           ('blockc', 'char'): 1}),
#  Counter({('ethereum', 'classic'): 1,
#           ('classic', 'blockchain'): 1,
#           ('blockchain', 'suffered'): 1,
#           ('suffered', 'attack'): 1,
#           ('attack', 'saturday'): 1,
#           ('saturday', 'evening'): 1,
#           ('evening', 'third'): 1,
#           ('third', 'attack'): 1,
#           ('attack', 'month'): 1,
#           ('month', 'noticed'): 1,
#           ('noticed', 'mining'): 1,
#           ('mining', 'company'): 1,
#           ('company', 'bitfly'): 1,
#           ('bitfly', 'also'): 1,
#           ('also', 'spotted'): 1,
#           ('spotted', 'first'): 1,
#           ('first', 'attack'): 1,
#           ('attack', 'aug'): 1,
#           ('aug', 'ullithe'): 1,
#           ('ullithe', 'char'): 1}),
#  Counter({('ethereum', 'ha'): 1,
#           ('ha', 'delayed'): 1,
#           ('delayed', 'may'): 1,
#           ('may', 'still'): 1,
#           ('still', 'see'): 1,
#           ('see', 'launch'): 1,
#           ('launch', 'eth'): 1,
#           ('eth', 'staking'): 1,
#           ('staking', 'fall'): 1,
#           ('fall', 'time'): 1,
#           ('time', 'investor'): 1,
#           ('investor', 'decide'): 1,
#           ('decide', 'stake'): 1,
#           ('stake', 'ethereum'): 1,
#           ('ethereum', 'promise'): 1,
#           ('promise', 'earnings'): 1,
#           ('earnings', 'char'): 1}),
#  Counter({('life', 'belt'): 1,
#           ('belt', 'bitcoin'): 1,
#           ('bitcoin', 'money'): 1,
#           ('money', 'sack'): 1,
#           ('sack', 'wood'): 1,
#           ('wood', 'floor'): 1,
#           ('floor', 'chalkboard'): 1,
#           ('chalkboard', 'background'): 1,
#           ('background', 'renderinggettylast'): 1,
#           ('renderinggettylast', 'week'): 1,
#           ('week', 'bitcoin'): 1,
#           ('bitcoin', 'experienced'): 1,
#           ('experienced', 'largest'): 1,
#           ('largest', 'weekly'): 1,
#           ('weekly', 'decline'): 1,
#           ('decline', 'since'): 1,
#           ('since', 'march'): 1,
#           ('march', 'initiated'): 1,
#           ('initiated', 'sudden'): 1,
#           ('sudden', 'strength'): 1,
#           ('strength', 'char'): 1}),
#  Counter({('investors', 'primarily'): 1,
#           ('primarily', 'treat'): 1,
#           ('treat', 'bitcoin'): 1,
#           ('bitcoin', 'btcusd'): 1,
#           ('btcusd', 'scarce'): 1,
#           ('scarce', 'asset'): 1,
#           ('asset', 'lends'): 1,
#           ('lends', 'number'): 1,
#           ('number', 'valuation'): 1,
#           ('valuation', 'approach'): 1,
#           ('approach', 'appear'): 1,
#           ('appear', 'work'): 1,
#           ('work', 'reasonably'): 1,
#           ('reasonably', 'well'): 1,
#           ('well', 'ethereum'): 1,
#           ('ethereum', 'ethusd'): 1,
#           ('ethusd', 'smart'): 1,
#           ('smart', 'contract'): 1,
#           ('contract', 'platfo'): 1,
#           ('platfo', 'char'): 1}),
#  Counter({('billion', 'worth'): 1,
#           ('worth', 'token'): 1,
#           ('token', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'missing'): 1,
#           ('missing', 'software'): 1,
#           ('software', 'standard'): 1,
#           ('standard', 'released'): 1,
#           ('released', 'setting'): 1,
#           ('setting', 'hijacked'): 1,
#           ('hijacked', 'drained'): 1,
#           ('drained', 'trading'): 1,
#           ('trading', 'exchange'): 1,
#           ('exchange', 'according'): 1,
#           ('according', 'new'): 1,
#           ('new', 'resear'): 1,
#           ('resear', 'char'): 1}),
#  Counter({('prices', 'ren'): 1,
#           ('ren', 'token'): 1,
#           ('token', 'renvm'): 1,
#           ('renvm', 'defi'): 1,
#           ('defi', 'network'): 1,
#           ('network', 'surged'): 1,
#           ('surged', 'past'): 1,
#           ('past', 'week'): 1,
#           ('week', 'thats'): 1,
#           ('thats', 'total'): 1,
#           ('total', 'amount'): 1,
#           ('amount', 'renbtc'): 1,
#           ('renbtc', 'tokenized'): 1,
#           ('tokenized', 'bitcoin'): 1,
#           ('bitcoin', 'locked'): 1,
#           ('locked', 'renvm'): 1,
#           ('renvm', 'broke'): 1,
#           ('broke', 'char'): 1}),
#  Counter({('eoseos', 'slid'): 1,
#           ('slid', 'tuesday'): 1,
#           ('tuesday', 'reversing'): 1,
#           ('reversing', 'gain'): 1,
#           ('gain', 'monday'): 1,
#           ('monday', 'eos'): 1,
#           ('eos', 'ended'): 1,
#           ('ended', 'day'): 1,
#           ('day', 'mixed'): 1,
#           ('mixed', 'start'): 1,
#           ('start', 'day'): 1,
#           ('day', 'saw'): 1,
#           ('saw', 'eos'): 1,
#           ('eos', 'rise'): 1,
#           ('rise', 'early'): 1,
#           ('early', 'morning'): 1,
#           ('morning', 'intraday'): 1,
#           ('intraday', 'high'): 1,
#           ('high', 'hitting'): 1,
#           ('hitting', 'char'): 1}),
#  Counter({('eoseos', 'slid'): 1,
#           ('slid', 'monday'): 1,
#           ('monday', 'following'): 1,
#           ('following', 'loss'): 1,
#           ('loss', 'sunday'): 1,
#           ('sunday', 'eos'): 1,
#           ('eos', 'ended'): 1,
#           ('ended', 'day'): 1,
#           ('day', 'wa'): 1,
#           ('wa', 'mixed'): 1,
#           ('mixed', 'start'): 1,
#           ('start', 'day'): 1,
#           ('day', 'eos'): 1,
#           ('eos', 'rose'): 1,
#           ('rose', 'early'): 1,
#           ('early', 'morning'): 1,
#           ('morning', 'intraday'): 1,
#           ('intraday', 'high'): 1,
#           ('high', 'h'): 1,
#           ('h', 'char'): 1}),
#  Counter({('signature', 'bank'): 1,
#           ('bank', 'gave'): 1,
#           ('gave', 'dozen'): 1,
#           ('dozen', 'small'): 1,
#           ('small', 'business'): 1,
#           ('business', 'ppp'): 1,
#           ('ppp', 'loan'): 1,
#           ('loan', 'crypto'): 1,
#           ('crypto', 'firm'): 1,
#           ('firm', 'previously'): 1,
#           ('previously', 'known'): 1,
#           ('known', 'ethereum'): 1,
#           ('ethereum', 'classic'): 1,
#           ('classic', 'ha'): 1,
#           ('ha', 'suffered'): 1,
#           ('suffered', 'another'): 1,
#           ('another', 'attack'): 1,
#           ('attack', 'digital'): 1,
#           ('digital', 'yuan'): 1,
#           ('yuan', 'wallet'): 1,
#           ('wallet', 'went'): 1,
#           ('went', 'live'): 1,
#           ('live', 'disappeare'): 1,
#           ('disappeare', 'char'): 1}),
#  Counter({('mongolian', 'authority'): 1,
#           ('authority', 'put'): 1,
#           ('put', 'kibosh'): 1,
#           ('kibosh', 'cheap'): 1,
#           ('cheap', 'electricity'): 1,
#           ('electricity', 'crypto'): 1,
#           ('crypto', 'miner'): 1,
#           ('miner', 'venezuela'): 1,
#           ('venezuela', 'seeing'): 1,
#           ('seeing', 'healthy'): 1,
#           ('healthy', 'crypto'): 1,
#           ('crypto', 'use'): 1,
#           ('use', 'outside'): 1,
#           ('outside', 'governmentapproved'): 1,
#           ('governmentapproved', 'exchange'): 1,
#           ('exchange', 'critical'): 1,
#           ('critical', 'bug'): 1,
#           ('bug', 'ha'): 1,
#           ('ha', 'left'): 1,
#           ('left', 'ether'): 1,
#           ('ether', 'char'): 1}),
#  Counter({('historic', 'fee'): 1,
#           ('fee', 'pressure'): 1,
#           ('pressure', 'plaguing'): 1,
#           ('plaguing', 'ethereum'): 1,
#           ('ethereum', 'blockchain'): 1,
#           ('blockchain', 'forcing'): 1,
#           ('forcing', 'one'): 1,
#           ('one', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'hottest'): 1,
#           ('hottest', 'project'): 1,
#           ('project', 'consider'): 1,
#           ('consider', 'swapping'): 1,
#           ('swapping', 'tire'): 1,
#           ('tire', 'drivingdigital'): 1,
#           ('drivingdigital', 'asset'): 1,
#           ('asset', 'trust'): 1,
#           ('trust', 'company'): 1,
#           ('company', 'bitgo'): 1,
#           ('bitgo', 'char'): 1}),
#  Counter({('another', 'contender'): 1,
#           ('contender', 'joining'): 1,
#           ('joining', 'ring'): 1,
#           ('ring', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'platform'): 1,
#           ('platform', 'sparring'): 1,
#           ('sparring', 'win'): 1,
#           ('win', 'market'): 1,
#           ('market', 'share'): 1,
#           ('share', 'ethereum'): 1,
#           ('ethereum', 'ecosystemava'): 1,
#           ('ecosystemava', 'labs'): 1,
#           ('labs', 'launching'): 1,
#           ('launching', 'avalanche'): 1,
#           ('avalanche', 'blockchain'): 1,
#           ('blockchain', 'next'): 1,
#           ('next', 'monday'): 1,
#           ('monday', 'char'): 1}),
#  Counter({('ethereum', 'classic'): 2,
#           ('classic', 'etc'): 1,
#           ('etc', 'labs'): 1,
#           ('labs', 'proposed'): 1,
#           ('proposed', 'multistage'): 1,
#           ('multistage', 'strategy'): 1,
#           ('strategy', 'wednesday'): 1,
#           ('wednesday', 'combat'): 1,
#           ('combat', 'risk'): 1,
#           ('risk', 'attack'): 1,
#           ('attack', 'roiled'): 1,
#           ('roiled', 'network'): 1,
#           ('network', 'recent'): 1,
#           ('recent', 'weeksas'): 1,
#           ('weeksas', 'block'): 1,
#           ('block', 'ha'): 1,
#           ('ha', 'reported'): 1,
#           ('reported', 'ethereum'): 1,
#           ('classic', 'char'): 1}),
#  Counter({('mongolian', 'authority'): 1,
#           ('authority', 'put'): 1,
#           ('put', 'kibosh'): 1,
#           ('kibosh', 'cheap'): 1,
#           ('cheap', 'electricity'): 1,
#           ('electricity', 'crypto'): 1,
#           ('crypto', 'miner'): 1,
#           ('miner', 'venezuela'): 1,
#           ('venezuela', 'seeing'): 1,
#           ('seeing', 'healthy'): 1,
#           ('healthy', 'crypto'): 1,
#           ('crypto', 'use'): 1,
#           ('use', 'outside'): 1,
#           ('outside', 'governmentapproved'): 1,
#           ('governmentapproved', 'exchange'): 1,
#           ('exchange', 'critical'): 1,
#           ('critical', 'bug'): 1,
#           ('bug', 'ha'): 1,
#           ('ha', 'left'): 1,
#           ('left', 'ether'): 1,
#           ('ether', 'char'): 1}),
#  Counter({('medalla', 'testnet'): 1,
#           ('testnet', 'went'): 1,
#           ('went', 'live'): 1,
#           ('live', 'last'): 1,
#           ('last', 'month'): 1,
#           ('month', 'ethereum'): 1,
#           ('ethereum', 'getting'): 1,
#           ('getting', 'one'): 1,
#           ('one', 'dress'): 1,
#           ('dress', 'rehearsal'): 1,
#           ('rehearsal', 'eventual'): 1,
#           ('eventual', 'launch'): 1,
#           ('launch', 'next'): 1,
#           ('next', 'iteration'): 1,
#           ('iteration', 'ethereum'): 1,
#           ('ethereum', 'monday'): 1,
#           ('monday', 'blog'): 1,
#           ('blog', 'post'): 1,
#           ('post', 'eth'): 1,
#           ('eth', 'devel'): 1,
#           ('devel', 'char'): 1}),
#  Counter({('ethereum', 'miner'): 2,
#           ('miner', 'gaining'): 1,
#           ('gaining', 'big'): 1,
#           ('big', 'transaction'): 1,
#           ('transaction', 'cost'): 1,
#           ('cost', 'gas'): 1,
#           ('gas', 'fee'): 1,
#           ('fee', 'continue'): 1,
#           ('continue', 'rise'): 1,
#           ('rise', 'amid'): 1,
#           ('amid', 'decentralized'): 1,
#           ('decentralized', 'finance'): 1,
#           ('finance', 'defi'): 1,
#           ('defi', 'boomaccording'): 1,
#           ('boomaccording', 'block'): 1,
#           ('block', 'research'): 1,
#           ('research', 'ethereum'): 1,
#           ('miner', 'generated'): 1,
#           ('generated', 'alltime'): 1,
#           ('alltime', 'high'): 1,
#           ('high', 'fee'): 1,
#           ('fee', 'char'): 1}),
#  Counter({('leading', 'crypto'): 1,
#           ('crypto', 'exchange'): 1,
#           ('exchange', 'binance'): 1,
#           ('binance', 'launching'): 1,
#           ('launching', 'cryptosafe'): 1,
#           ('cryptosafe', 'alliance'): 1,
#           ('alliance', 'platform'): 1,
#           ('platform', 'partnership'): 1,
#           ('partnership', 'oasis'): 1,
#           ('oasis', 'labs'): 1,
#           ('labs', 'data'): 1,
#           ('data', 'privacy'): 1,
#           ('privacy', 'company'): 1,
#           ('company', 'prevent'): 1,
#           ('prevent', 'analyze'): 1,
#           ('analyze', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'fraudullicalling'): 1,
#           ('fraudullicalling', 'char'): 1}),
#  Counter({('stablecoin', 'issuer'): 1,
#           ('issuer', 'tether'): 1,
#           ('tether', 'today'): 1,
#           ('today', 'moving'): 1,
#           ('moving', 'billion'): 1,
#           ('billion', 'usdt'): 1,
#           ('usdt', 'coin'): 1,
#           ('coin', 'total'): 1,
#           ('total', 'supply'): 1,
#           ('supply', 'tron'): 1,
#           ('tron', 'ethereum'): 1,
#           ('ethereum', 'blockchaintether'): 1,
#           ('blockchaintether', 'cto'): 1,
#           ('cto', 'paolo'): 1,
#           ('paolo', 'ardoino'): 1,
#           ('ardoino', 'told'): 1,
#           ('told', 'block'): 1,
#           ('block', 'cryptocurrency'): 1,
#           ('cryptocurrency', 'exchange'): 1,
#           ('exchange', 'char'): 1}),
#  Counter({('cryptocurrency', 'exchange'): 1,
#           ('exchange', 'kraken'): 1,
#           ('kraken', 'seeking'): 1,
#           ('seeking', 'ethereum'): 1,
#           ('ethereum', 'specialist'): 1,
#           ('specialist', 'serve'): 1,
#           ('serve', 'face'): 1,
#           ('face', 'firm'): 1,
#           ('firm', 'endeavor'): 1,
#           ('endeavor', 'ecosystemaccording'): 1,
#           ('ecosystemaccording', 'job'): 1,
#           ('job', 'posting'): 1,
#           ('posting', 'lead'): 1,
#           ('lead', 'ethereum'): 1,
#           ('ethereum', 'strategist'): 1,
#           ('strategist', 'position'): 1,
#           ('position', 'woul'): 1,
#           ('woul', 'char'): 1})]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
bitcoin_top10 = token_count(bitcoin_df['tokens'].explode(), 10)
bitcoin_top10
# Out:
# [('char', 94),
#  ('bitcoin', 91),
#  ('satoshi', 42),
#  ('nakaboto', 42),
#  ('every', 23),
#  ('going', 23),
#  ('another', 22),
#  ('edition', 22),
#  ('ha', 21),
#  ('robot', 21)]

# %%
# Get the top 10 words for Ethereum
ethereum_top10 = token_count(ethereum_df['tokens'].explode(), 10)
ethereum_top10
# Out:
# [('char', 94),
#  ('ethereum', 63),
#  ('ha', 28),
#  ('bitcoin', 24),
#  ('blockchain', 18),
#  ('decentralized', 16),
#  ('defi', 15),
#  ('cryptocurrency', 14),
#  ('exchange', 14),
#  ('network', 14)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_wordcloud = WordCloud().generate(' '.join(map(str, list(bitcoin_df['tokens'].explode()))))
plt.imshow(bitcoin_wordcloud)

# %%
# Generate the Ethereum word cloud
ethereum_wordcloud = WordCloud().generate(' '.join(map(str, list(ethereum_df['tokens'].explode()))))
plt.imshow(ethereum_wordcloud)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_text_concat = ' '.join(map(str, list(bitcoin_df['text'].explode())))
bitcoin_text_concat
# Out:
# 'Two alleged crypto traders in Singapore apparently came up with a fool-proof plan: rather than convert a customers 365,000 Singapore dollars to bitcoin, they would simply rob the victim when he came … [+1735 chars] By Alexis Akwagyiram, Tom Wilson\r\n* Monthly crypto transfers to and from Africa rise 55% in a year\r\n* Much of the activity in Nigeria, South Africa and Kenya\r\n* Driven by small businesses and migrant… [+7730 chars] “The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate VPN and elimination of in-person verification, which can partially explain the succes… [+3548 chars] LAGOS/LONDON (Reuters) - Four months ago, Abolaji Odunjo made a fundamental change to his business selling mobile phones in a bustling street market in Lagos: He started paying his suppliers in bitco… [+7646 chars] LAGOS/LONDON (Reuters) - Four months ago, Abolaji Odunjo made a fundamental change to his business selling mobile phones in a bustling street market in Lagos: He started paying his suppliers in bitco… [+7537 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2968 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2989 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2756 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2802 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2836 chars] FTX, a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquiring a popular portfolio tracking app, Blockfolio.\r\nFTX is spending $150 million for the acqu… [+1325 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3024 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2986 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2855 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2786 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2863 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2831 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2900 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to an ...

# %%
# Run the NER processor on all of the text
bitcoin_NER = nlp(bitcoin_text_concat)
bitcoin_NER
# Add a title to the document
bitcoin_NER.user_data["Title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_NER, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alleged crypto traders in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  apparently came up with a fool-proof plan: rather than convert a customers
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     365,000 Singapore dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , they would simply rob the victim when he came … [+1735 chars] By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexis Akwagyiram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tom Wilson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>*
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  crypto transfers to and from
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  rise
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     55%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>* Much of the activity in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kenya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>* Driven by small businesses and migrant… [+7730 chars] “The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VPN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and elimination of in-person verification, which can partially explain the succes… [+3548 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LAGOS/LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four months ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abolaji Odunjo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  made a fundamental change to his business selling mobile phones in a bustling street market in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lagos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# : He started paying his suppliers in bitco… [+7646 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LAGOS/LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four months ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text

# %%
# List all Entities
for i in bitcoin_NER.ents:
    print(i.text, i.label_)
# Out:
# Two CARDINAL
# Singapore GPE
# 365,000 Singapore dollars MONEY
# bitcoin GPE
# Alexis Akwagyiram PERSON
# Tom Wilson PERSON
# Monthly DATE
# Africa LOC
# 55% PERCENT
# a year DATE
# Nigeria GPE
# South Africa GPE
# Kenya GPE
# VPN PRODUCT
# LAGOS/LONDON ORG
# Reuters ORG
# Four months ago DATE
# Abolaji Odunjo ORG
# Lagos GPE
# LAGOS/LONDON ORG
# Reuters ORG
# Four months ago DATE
# Abolaji Odunjo ORG
# Lagos GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Blockfolio GPE
# FTX ORG
# $150 million MONEY
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# The Complete Stock and Cryptocurrency Investment Toolkit Bundle ORG
# 29.46 MONEY
# Sept. 7 DATE
# 97% PERCENT
# September DATE
# 18 DATE
# 2020 DATE
# 6 min QUANTITY
# five years ago DATE
# Ethereum ORG
# ETH ORG
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# Mac PERSON
# Xcode ORG
# Trend Micro ORG
# Crypto Valley LOC
# up to 100,000 Swiss francs MONEY
# about $110,000 MONEY
# Bitcoin GPE
# Ether PERSON
# Fe ORG
# Joe Sullivan PERSON
# U.S. GPE
# the United States District Court GPE
# the Northern District LOC
# Elon Musk ORG
# Tesla ORDINAL
# Thursday DATE
# Russian NORP
# Sept 2 DATE
# Reuters ORG
# 300 billion tenge MONEY
# $714 million MONEY
# Digital Development ORG
# Bagdat Mussin PERSON
# Wedn PERSON
# Lincolnshire GPE
# two CARDINAL
# three CARDINAL
# two CARDINAL
# Tesco ORG
# Nigel Wright PERSON
# Market Rasen PERSON
# Reuters ORG
# Binance ORG
# the Delta Summit EVENT
# Malta GPE
# Blockchain ORG
# Digital Innovation ORG
# Ta' GPE
# Qali WORK_OF_ART
# Reuters ORG
# March 28, 2018 DATE
# REUTERS/Dado Ruvic/Illust ORG
# BANGKOK ORG
# Reuters ORG
# Thailand GPE
# Thursday DATE
# Gove WORK_OF_ART
# at least a year DATE
# Bitcoin GPE
# around $690 million MONEY
# 69,370 CARDINAL
# BTC ORG
# seventh ORDINAL
# WASHINGTON GPE
# Reuters ORG
# Uber Technologies ORG
# Thursday DATE
# 2016 DATE
# about 57 mi CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Bitcoin GPE
# July DATE
# three CARDINAL
# US GPE
# UK GPE
# Knibbeler PERSON
# 'Current Studies' WORK_OF_ART
# 2013-2016 DATE
# 16-year-old DATE
# Massachusetts GPE
# July DATE
# Twitter ORG
# July DATE
# 17-year-old DATE
# Graham Clark PERSON
# Sept 10 DATE
# Reuters ORG
# Every week DATE
# Reuters ORG
# Sullivan PERSON
# up to eight years DATE
# one CARDINAL
# the past few years DATE
# Jeff Royder PERSON
# Acct Mgr PERSON
# Michael Scott PERSON
# Join Meeting ORG
# Zoom PERSON
# five CARDINAL
# one CARDINAL
# the past few years DATE
# just one CARDINAL
# just one CARDINAL
# $100 million MONEY
# Deloitte ORG
# KPMG ORG
# Fidelity ORG
# $100 milli MONEY
# Bryan Connor Herrell PERSON
# 11 years DATE
# US GPE
# Depa PERSON
# the wee hours of the morning TIME
# John Wick PERSON
# Twitter ORG
# Indian NORP
# Narendra Modis PERSON
# ul><li PERSON
# US NORP
# May 2018 DATE
# Tuesday DATE
# five days DATE
# weekly DATE
# Pardon The Intrusion ORG
# TNWs bi-weekly PERSON
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# the past few years DATE
# just one CARDINAL
# Nvidia ORG
# Sunday evening TIME
# Arm Limited PERSON
# SoftBank ORG
# $40 billion MONEY
# nine zeros CARDINAL
# Uber PERSON
# two CARDINAL
# 100,000 MONEY
# Bitcoin GPE
# Angela Lang PERSON
# The Department of Justice ORG
# Elon Musk ORG
# Twitter ORG
# Thursday DATE
# Tesla Nevada FAC
# Russian NORP
# recent weeks DATE
# Russian NORP
# Minecraft PERSON
# YouTube for hours TIME
# four CARDINAL
# Julija Adlesic PERSON
# Sky News ORG
# Slovenian NORP
# two years DATE
# Julija PERSON
# years DATE
# U.S. GPE
# Donald Trump PERSON
# Wednesday DATE
# American NORP
# two CARDINAL
# Tom PERSON
# Dancing Bug ORG
# Tom PERSON
# Trumpverse WORK_OF_ART
# The Super-Fun-Pak Comix Reader WORK_OF_ART
# Get Forbes' PERSON
# bitcoin GPE
# Indians NORP
# India GPE
# March DATE
# Indigo ORG
# Bitcoin GPE
# the last few months DATE
# 4,000 MONEY
# March DATE
# Get Forbes' PERSON
# bitcoin GPE
# Winklevoss PERSON
# Uber PERSON
# Joseph Sullivan PERSON
# US GPE
# 52-year-old DATE
# February 28, 2013 DATE
# REUTERS/Kacper Pempel/Illustration/File Photo/File Photo - Kacper Pempel/ ORG
# Germany GPE
# The weekend DATE
# Pour GPE
# French NORP
# Last month DATE
# Bitcoin GPE
# 10,000 MONEY
# 11,000 MONEY
# Bitcoin GPE
# Bitcoin GPE
# August DATE
# the end of July DATE
# a footing over $12,000 MONEY
# Bitcoin GPE
# this week DATE
# 5% PERCENT
# under 24 hours TIME
# 10,000 MONEY
# 1,000 MONEY
# Bitcoin GPE
# just ten years DATE
# bitcoin GPE
# second ORDINAL
# one CARDINAL
# bitcoin GPE
# more than 10% PERCENT
# 24-hour TIME
# morning TIME
# Bull Case / Bear Case: You WORK_OF_ART
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# NEW YORK CITY GPE
# NY ORG
# UNITED STATES GPE
# american NORP
# Fidelity Investments ORG
# Alex Tai PERSON
# Bitcoin GPE
# recent months DATE
# the Federal Reserve's ORG
# March DATE
# Bitcoin GPE
# Ryuk ORG
# $61 million MONEY
# 2018 DATE

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the ethereum text together
ethereum_text_concat = ' '.join(map(str, list(ethereum_df['text'].explode())))
ethereum_text_concat
# Out:
# 'If you\'ve interacted with cryptocurrencies in the past couple of years, there\'s a good chance you\'ve used MetaMask. It\'s a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars] TL;DR: The Complete Stock and Cryptocurrency Investment Toolkit Bundle is on sale for £29.46 as of Sept. 7, saving you 97% on list price.\r\nThe world of finance has always been complicated, and now th… [+2225 chars] September\r\n18, 2020\r\n6 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nFounded over five years ago, the Ethereum platform and its native ether (ETH)\xa0have existed mostly in t… [+6239 chars] LONDON (Reuters) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of about 20%. What could possibly g… [+7143 chars] NEW YORK (Reuters) - Brooklyn-based technology startup ConsenSys has acquired JPMorgan Chase &amp; Co’s (JPM.N) marquee blockchain platform Quorum, the companies said on Tuesday. \r\nAs part of the dea… [+1915 chars] An outspoken Bitcoin whale who rarely shows affection for anything other than BTC says two crypto assets have potential.\r\nThe pseudonymous trader known as Joe007 says UNUS SED LEO (LEO) may be a soli… [+1503 chars] TLDR: With the training in the Interactive Learn to Code Bundle, students tackle big coding topics through hands-on exercises to help the learning really stick.\r\nWhile coding is simple for some, that… [+2232 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3014 chars] Ethereum, having long played second fiddle to the number one cryptocurrency, bitcoin, is stepping into the limelight.\r\nThe ethereum price, climbing more than 10% over the last 24-hour trading period … [+2813 chars] $100 million blockchain startup BRD rolled out cryptocurrency tools and partnerships now used by Deloitte, KPMG, and Fidelity as part of its mission to make cryptocurrency more accessible\r\n$100 milli… [+4805 chars] Ethereum based Uniswap gave 400 UNI to all users that used the decentralized exchange prior to ... [+] September 1.\r\nGetty Images\r\nUniswap, the most widely utilized decentralized exchange on the Ethe… [+3383 chars] Female hand with twenty dollars on a white background.\r\ngetty\r\nSince May, Ethereum has outperformed bitcoin, largely due to the decentralized finance (DeFi) frenzy, which saw numerous DeFi tokens wit… [+2922 chars] POLAND - 2020/06/15: In this photo illustration an Ethereum logo seen displayed on a smartphone. ... [+] (Photo Illustration by Mateusz Slodkowski/SOPA Images/LightRocket via Getty Images)\r\nSOPA Imag… [+2371 chars] The price of Bitcoin looks to enter a new range after a key breakout.\r\nSOPA Images/LightRocket via Getty Images\r\nThe price of Bitcoin rose to as high as $12,086 on Coinbase, as Ethereum (ETH) buoyed … [+3138 chars] The Securities and Exchange Commission announced a settlement with esports-betting cryptocurrency firm Unikrn for alleged violations of securities laws. Unikrn will shutter its UnikoinGold cryptocurr… [+5630 chars] September\r\n16, 2020\r\n6 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nIn the past few months, a\xa0massive change in working dynamics has fueled an uptick in a kind of infecti… [+7072 chars] Over $1 billion worth of bitcoin has been tokenized on Ethereum as the total supply of tokenized bitcoin (BTC) passed 92,600 on Thursday, or 0.42% of the total BTC supply. In January, less than 1,200… [+946 chars] Today, the team behind the\xa0Baseline Protocol\xa0-\xa0an enterprise focused blockchain projects pioneered by\xa0\xa0by\xa0EY, Microsoft, ConsenSys,\xa0AMD and others that uses the public Ethereum blockchain announced s… [+11026 chars] A "hack-proof" smart padlock with security based on bl ...

# %%
# Run the NER processor on all of the text
ethereum_NER = nlp(ethereum_text_concat)
ethereum_NER
# Add a title to the document
ethereum_NER.user_data['Title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(ethereum_NER, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">If you've interacted with cryptocurrencies in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past couple of years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars] TL;DR:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Complete Stock and Cryptocurrency Investment Toolkit Bundle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.46
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sept. 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>The world of finance has always been complicated, and now th… [+2225 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 min
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# </br>Founded over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  platform and its native ether (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) have existed mostly in t… [+6239 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 20%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . What could possibly g… [+7143 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEW YORK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based technology startup
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConsenSys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has acquired
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan Chase &amp;amp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; Co’s (JPM.N) marquee blockchain platform
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quorum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the companies said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em

# %%
# List all Entities
for i in ethereum_NER.ents:
    print(i.text, i.label_)
# Out:
# the past couple of years DATE
# The Complete Stock and Cryptocurrency Investment Toolkit Bundle ORG
# 29.46 MONEY
# Sept. 7 DATE
# 97% PERCENT
# September DATE
# 18 DATE
# 2020 DATE
# 6 min QUANTITY
# five years ago DATE
# Ethereum ORG
# ETH ORG
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# NEW YORK PERSON
# Reuters ORG
# Brooklyn GPE
# ConsenSys ORG
# JPMorgan Chase &amp ORG
# Quorum PRODUCT
# Tuesday DATE
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# second ORDINAL
# one CARDINAL
# bitcoin GPE
# more than 10% PERCENT
# 24-hour TIME
# $100 million MONEY
# Deloitte ORG
# KPMG ORG
# Fidelity ORG
# $100 milli MONEY
# Uniswap ORG
# 400 CARDINAL
# UNI ORG
# September 1 DATE
# twenty dollars MONEY
# May DATE
# bitcoin GPE
# DeFi LOC
# DeFi LOC
# Ethereum ORG
# Mateusz Slodkowski/ PERSON
# Bitcoin GPE
# Bitcoin GPE
# as high as $12,086 MONEY
# Ethereum (ETH ORG
# The Securities and Exchange Commission ORG
# Unikrn ORG
# Unikrn ORG
# UnikoinGold ORG
# September DATE
# 16 DATE
# 2020 DATE
# 6 min QUANTITY
# the past few months DATE
# working dynamics ORG
# $1 billion MONEY
# bitcoin GPE
# BTC ORG
# 92,600 CARDINAL
# Thursday DATE
# 0.42% PERCENT
# BTC ORG
# January DATE
# less than 1,200 CARDINAL
# Today DATE
# Baseline Protocol PRODUCT
# EY GPE
# Microsoft ORG
# ConsenSys ORG
# AMD ORG
# 1kg QUANTITY
# $7 million MONEY
# the past month DATE
# ul><li GPE
# Bitcoin GPE
# BTC ORG
# around $12,00 MONEY
# AR ORG
# AI GPE
# European NORP
# this week DATE
# Smart PERSON
# Ethereum ( ORG
# DeFi ORG
# DeFi LOC
# Bitcoin GPE
# Monday DATE
# September DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $10,669 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 3.4% PERCENT
# the previous 24 DATE
# second ORDINAL
# three weeks DATE
# ul><li PERSON
# Tuesday DATE
# Bitcoin GPE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,298 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 3.8% PERCENT
# Bitcoin GPE
# Thursday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $10,920 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 0.73% PERCENT
# the previous 24 hour TIME
# Ethereum 2.0 ORG
# CoinDesk Research ORG
# Christine Kim PERSON
# Ben Edgington PERSON
# Vijay Michalik PERSON
# Tether PERSON
# Tether PERSON
# U.S. GPE
# today DATE
# two CARDINAL
# Russian NORP
# nearly $17 million MONEY
# DEFI ORG
# INX ORG
# 1 billion CARDINAL
# Tron to Ethereum ORG
# bitcoin GPE
# Blockchai GPE
# Baseline Protocol PERSON
# Version 1.0 PRODUCT
# Wednesday DATE
# Micr PERSON
# JPMorgan Chase ORG
# ConsenSys ORG
# Brooklyn GPE
# JPMorgan ORG
# un ORG
# DeFi ORG
# DeFi Pulse PERSON
# 1.47 MONEY
# last month DATE
# the U.S. Office of the Comptroller of the Currency ORG
# OCC ORG
# just above $10,000 MONEY
# CoinDesks Markets Daily ORG
# Bitcoin GPE
# Wednesday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,396 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 4.8% PERCENT
# the previous 24 hours TIME
# the Ethereum 2.0 ORG
# above $11 MONEY
# DeFi ORG
# Ethereum, CoinDesks Markets Daily ORG
# before our regular noon TIME
# more than $1 billion MONEY
# China GPE
# Ethereum Classic FAC
# Blockchain Bites WORK_OF_ART
# daily DATE
# Takeaway ORG
# ul><li PERSON
# the LNP/BP Standards Association ORG
# RGB ORG
# June.</li><li GPE
# second ORDINAL
# years DATE
# USDT ORG
# U.S. GPE
# Berlin GPE
# $1.2 million MONEY
# Polkadot ORG
# IOSG Ventures ORG
# Galaxy Digital PERSON
# 30% PERCENT
# Uniswap ORG
# UNI ORG
# around 00:30 TIME
# Thursday DATE
# zero CARDINAL
# as many as 15 CARDINAL
# OMG Network ORG
# the past week DATE
# CoinGecko ORG
# Leah Callon-Butler PERSON
# Emfarsis ORG
# Asia LOC
# the early 1980s DATE
# Ethereum Classics ORG
# January DATE
# two CARDINAL
# 51% PERCENT
# August DATE
# 2 MONEY
# last week DATE
# Algorand ORG
# US GPE
# three 51% PERCENT
# a month DATE
# Ethereum Classics ORG
# the past month DATE
# 13% PERCENT
# First ORDINAL
# May and June DATE
# GitHub ORG
# DeFi PERSON
# Protocol PRODUCT
# Polkadot ORG
# weeks DATE
# today DATE
# developer house Snowfork ORG
# Chainlink ORG
# Arbol ORG
# Arbol ORG
# BTC ORG
# LTC ORG
# Coinbase PRODUCT
# recent weeks DATE
# first ORDINAL
# U.S. GPE
# the two weeks DATE
# INX Ltd. ORG
# more than 350 CARDINAL
# Swisscom WORK_OF_ART
# the Web3 Foundation ORG
# Thursday DATE
# the Financial Industry Regulatory Authority ORG
# FINRA ORG
# Diogenes WORK_OF_ART
# a Verifiable Delay Function ORG
# VDF ORG
# CryptoKitties ORG
# 2017 DATE
# Stefan George of Gnosis PERSON
# Uniswaps ORG
# UNI ORG
# Wednesday night TIME
# the past 24 hours TIME
# UNI ORG
# Bloomberg News ORG
# Mathew Leising PERSON
# Out of the Ether: The Amazing Story of Ethereum WORK_OF_ART
# $55 Million MONEY
# second ORDINAL
# Thursday DATE
# a record $16 million MONEY
# Kava Labs PERSON
# first ORDINAL
# DeFi ORG
# BTC ORG
# Harvest ORG
# One dollar MONEY
# Ethereum ORG
# Tuesday DATE
# DeFi ORG
# Ethereum 2.0 ORG
# Danny Ryan PERSON
# the Ethereum Foundation ORG
# today DATE
# Ethereum Classic ORG
# 51% PERCENT
# Saturday DATE
# evening TIME
# third ORDINAL
# 51% PERCENT
# this month DATE
# Bitfly ORG
# first ORDINAL
# Aug. 1 DATE
# ul><li PERSON
# Ethereum 2.0 ORG
# ETH ORG
# Fall 2020 DATE
# 5-10% PERCENT
# Bitcoin Money Sack on Wood Floor - Chalkboard Background - 3D ORG
# Last week DATE
# bitcoin GPE
# weekly DATE
# March DATE
# Bitcoin GPE
# BTC-USD ORG
# ETH-USD ORG
# $1 billion MONEY
# 2017 DATE
# RenVM DeFi GPE
# more than 100% PERCENT
# the past week DATE
# RenVM GPE
# 10,000 CARDINAL
# 7.77% PERCENT
# Tuesday DATE
# 1.99% PERCENT
# Monday DATE
# the day DATE
# 3.1234 MONEY
# the day DATE
# early morning TIME
# 3.3961 MONEY
# 2.05% PERCENT
# Monday DATE
# 1.16% PERCENT
# Sunday DATE
# the day DATE
# 2.8437 MONEY
# the day DATE
# early morning TIME
# 2.9416 MONEY
# Signature Bank ORG
# dozens CARDINAL
# Ethereum Classic ORG
# another 51% PERCENT
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# one CARDINAL
# Digital ORG
# DeFi ORG
# Ava Labs ORG
# Avalanche ORG
# next Monday DATE
# Ethereum Classic ORG
# Wednesday DATE
# 51% PERCENT
# recent weeks DATE
# Ethereum Classic PRODUCT
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# Medalla PERSON
# last month DATE
# Ethereum ORG
# one CARDINAL
# Ethereum 2.0 ORG
# Monday DATE
# ETH ORG
# DeFi ORG
# The Block Research ORG
# CryptoSafe Alliance ORG
# Oasis Labs ORG
# ul><li PERSON
# Tether PERSON
# today DATE
# 1 billion USDT MONEY
# 8% PERCENT
# TRON ORG
# Tether PERSON
# Paolo Ardoino PERSON
# Kraken PERSON
